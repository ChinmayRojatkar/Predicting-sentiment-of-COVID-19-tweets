# %% [markdown]
# <a href="https://colab.research.google.com/github/gkunal8019/Predicting-sentiment-of-COVID-19-tweets/blob/main/Predicting_sentiment_of_COVID_19_tweets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <b><u> Project Title : Sentiment Analysis : Predicting sentiment of COVID-19 tweets</u></b>

# %% [markdown]
# ## <b> Problem Description </b>
#
# ### This challenge asks you to build a classification model to predict the sentiment of COVID-19 tweets.The tweets have been pulled from Twitter and manual tagging has been done then.
#
# ### The names and usernames have been given codes to avoid any privacy concerns.
#
# ### You are given the following information:
# 1. Location
# 2. Tweet At
# 3. Original Tweet
# 4. Label

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
import re
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns

nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df=pd.read_csv('/content/drive/MyDrive/capstone project/Sentiment Analysis : Predicting sentiment of COVID-19 tweets/Coronavirus Tweets.csv',encoding="ISO-8859-1")

# %%
df.head()
# Out:
#    UserName  ScreenName   Location     TweetAt  \
# 0      3799       48751     London  16-03-2020
# 1      3800       48752         UK  16-03-2020
# 2      3801       48753  Vagabonds  16-03-2020
# 3      3802       48754        NaN  16-03-2020
# 4      3803       48755        NaN  16-03-2020
#
#                                        OriginalTweet           Sentiment
# 0  @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...             Neutral
# 1  advice Talk to your neighbours family to excha...            Positive
# 2  Coronavirus Australia: Woolworths to give elde...            Positive
# 3  My food stock is not the only one which is emp...            Positive
# 4  Me, ready to go at supermarket during the #COV...  Extremely Negative

# %%
df.tail()
# Out:
#        UserName  ScreenName                      Location     TweetAt  \
# 41152     44951       89903  Wellington City, New Zealand  14-04-2020
# 41153     44952       89904                           NaN  14-04-2020
# 41154     44953       89905                           NaN  14-04-2020
# 41155     44954       89906                           NaN  14-04-2020
# 41156     44955       89907  i love you so much || he/him  14-04-2020
#
#                                            OriginalTweet           Sentiment
# 41152  Airline pilots offering to stock supermarket s...             Neutral
# 41153  Response to complaint not provided citing COVI...  Extremely Negative
# 41154  You know itÂs getting tough when @KameronWild...            Positive
# 41155  Is it wrong that the smell of hand sanitizer i...             Neutral
# 41156  @TartiiCat Well new/used Rift S are going for ...            Negative

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41157 entries, 0 to 41156
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UserName       41157 non-null  int64
#  1   ScreenName     41157 non-null  int64
#  2   Location       32567 non-null  object
#  3   TweetAt        41157 non-null  object
#  4   OriginalTweet  41157 non-null  object
#  5   Sentiment      41157 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 1.9+ MB

# %% [markdown]
# LOOKING FOR NAN VALUES

# %%
df.isnull().sum()
# Out:
# UserName            0
# ScreenName          0
# Location         8590
# TweetAt             0
# OriginalTweet       0
# Sentiment           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['UserName', 'ScreenName', 'Location', 'TweetAt', 'OriginalTweet',
#        'Sentiment'],
#       dtype='object')

# %%
df['Sentiment'].value_counts()
# Out:
# Positive              11422
# Negative               9917
# Neutral                7713
# Extremely Positive     6624
# Extremely Negative     5481
# Name: Sentiment, dtype: int64

# %%
df_sent = df['Sentiment'].value_counts()

plt.pie(df_sent, labels = df_sent.index,radius=2);

# %% [markdown]
# Positive and negative have the highest Sentiment

# %%
#top 10 location 
df_locn = df['Location'].value_counts().head(10)
print(df_locn)
# Out:
# London             540
# United States      528
# London, England    520
# New York, NY       395
# Washington, DC     373
# United Kingdom     337
# Los Angeles, CA    281
# India              268
# UK                 232
# Australia          225
# Name: Location, dtype: int64

# %%
# Plotinh with seaborn top 10 location 
df_top = pd.DataFrame(df_locn.items(),columns=['Country','counts']) #The items() method returns a view object. The view object contains the key-value pairs of the dictionary, as tuples in a list.
df_top
# Out:
#            Country  counts
# 0           London     540
# 1    United States     528
# 2  London, England     520
# 3     New York, NY     395
# 4   Washington, DC     373
# 5   United Kingdom     337
# 6  Los Angeles, CA     281
# 7            India     268
# 8               UK     232
# 9        Australia     225

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Country',y='counts',data=df_top)
plt.show()

# %% [markdown]
# 1. LONDON , UNITED STATE AND ENGLAND HAS THE HIGEST TWEETS SENTIMENT
# 2. AUSTRALIA AND UK HAS THE LOWEST TEWWTS SENTIMENTS

# %%
df.OriginalTweet
# Out:
# 0        @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...
# 1        advice Talk to your neighbours family to excha...
# 2        Coronavirus Australia: Woolworths to give elde...
# 3        My food stock is not the only one which is emp...
# 4        Me, ready to go at supermarket during the #COV...
#                                ...
# 41152    Airline pilots offering to stock supermarket s...
# 41153    Response to complaint not provided citing COVI...
# 41154    You know itÂs getting tough when @KameronWild...
# 41155    Is it wrong that the smell of hand sanitizer i...
# 41156    @TartiiCat Well new/used Rift S are going for ...
# Name: OriginalTweet, Length: 41157, dtype: object

# %%
range(0,len(df.OriginalTweet))
# Out:
# range(0, 41157)

# %% [markdown]
# ## Text Analysis of tweet

# %%
pip install neattext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: neattext in /usr/local/lib/python3.7/dist-packages (0.1.3)

# %%
import neattext.functions as nfx

# %%
# Methods/Attrib
dir(nfx)
# Out:
# ['BTC_ADDRESS_REGEX',
#  'CURRENCY_REGEX',
#  'CURRENCY_SYMB_REGEX',
#  'Counter',
#  'DATE_REGEX',
#  'EMAIL_REGEX',
#  'EMOJI_REGEX',
#  'HASTAG_REGEX',
#  'MASTERCard_REGEX',
#  'MD5_SHA_REGEX',
#  'MOST_COMMON_PUNCT_REGEX',
#  'NUMBERS_REGEX',
#  'PHONE_REGEX',
#  'PoBOX_REGEX',
#  'SPECIAL_CHARACTERS_REGEX',
#  'STOPWORDS',
#  'STOPWORDS_de',
#  'STOPWORDS_en',
#  'STOPWORDS_es',
#  'STOPWORDS_fr',
#  'STOPWORDS_ru',
#  'STOPWORDS_yo',
#  'STREET_ADDRESS_REGEX',
#  'TextFrame',
#  'URL_PATTERN',
#  'USER_HANDLES_REGEX',
#  'VISACard_REGEX',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__generate_text',
#  '__loader__',
#  '__name__',
#  '__numbers_dict',
#  '__package__',
#  '__spec__',
#  '_lex_richness_herdan',
#  '_lex_richness_maas_ttr',
#  'clean_text',
#  'defaultdict',
#  'digit2words',
#  'extract_btc_address',
#  'extract_currencies',
#  'extract_currency_symbols',
#  'extract_dates',
#  'extract_emails',
#  'extract_emojis',
#  'extract_hashtags',
#  'extract_html_tags',
#  'extract_mastercard_addr',
#  'extract_md5sha',
#  'extract_numbers',
#  'extract_pattern',
#  'extract_phone_numbers',
#  'extract_postoffice_box',
#  'extract_shortwords',
#  'extract_special_characters',
#  'extract_stopwords',
#  'extract_street_address',
#  'extract_terms_in_bracket',
#  'extract_urls',
#  'extract_userhandles',
#  'extract_visacard_addr',
#  'fix_contractions',
#  'generate_sentence',
#  'hamming_distance',
#  'inverse_df',
#  'lexical_richness',
#  'markov_chain',
#  'math',
#  'nlargest',
#  'normalize',
#  'num2words',
#  'random',
#  're',
#  'read_txt',
#  'remove_accents',
#  'remove_bad_quotes',
#  'remove_btc_address',
#  'remove_currencies',
#  'remove_currency_symbols',
#  'remove_custom_pattern',
#  'remove_custom_words',
#  'remove_dates',
#  'remove_emails',
#  'remove_emojis',
#  'remove_hashtags',
#  'remove_html_tags',
#  'remove_mastercard_addr',
#  'remove_md5sha',
#  'remove_multiple_spaces',
#  'remove_non_ascii',
#  'remove_numbers',
#  'remove_phone_numbers',
#  'remove_postoffice_box',
#  'remove_puncts',
#  'remove_punctuations',
#  'remove_shortwords',
#  'remove_special_characters',
#  'remove_stopwords',
#  'remove_street_address',
#  'remove_terms_in_bracket',
#  'remove_urls',
#  'remove_userhandles',
#  'remove_visacard_addr',
#  'replace_bad_quotes',
#  'replace_currencies',
#  'replace_currency_symbols',
#  'replace_dates',
#  'replace_emails',
#  'replace_emojis',
#  'replace_numbers',
#  'replace_phone_numbers',
#  'replace_special_characters',
#  'replace_term',
#  'replace_urls',
#  'string',
#  'term_freq',
#  'to_txt',
#  'unicodedata',
#  'word_freq',
#  'word_length_freq']

# %%
df['OriginalTweet'].iloc[5]
# Out:
# 'As news of the regionÂ\x92s first confirmed COVID-19 case came out of Sullivan County last week, people flocked to area stores to purchase cleaning supplies, hand sanitizer, food, toilet paper and other goods, @Tim_Dodson reports https://t.co/cfXch7a2lU'

# %% [markdown]
# Noise
# 1. remove mentions/userhandles
# 2. remove hashtags
# 3. urls
# 4. emojis
# 5. special char

# %%
df['OriginalTweet'].head(10)
# Out:
# 0    @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...
# 1    advice Talk to your neighbours family to excha...
# 2    Coronavirus Australia: Woolworths to give elde...
# 3    My food stock is not the only one which is emp...
# 4    Me, ready to go at supermarket during the #COV...
# 5    As news of the regionÂs first confirmed COVID...
# 6    Cashier at grocery store was sharing his insig...
# 7    Was at the supermarket today. Didn't buy toile...
# 8    Due to COVID-19 our retail store and classroom...
# 9    For corona prevention,we should stop to buy th...
# Name: OriginalTweet, dtype: object

# %%
df['OriginalTweet'].apply(nfx.extract_hashtags)
# Out:
# 0                                                       []
# 1                                                       []
# 2                                                       []
# 3        [#COVID19france, #COVID_19, #COVID19, #coronav...
# 4        [#COVID19, #coronavirus, #CoronavirusFrance, #...
#                                ...
# 41152                                     [#NZ, #COVID-19]
# 41153                                                   []
# 41154                         [#coronavirus, #toiletpaper]
# 41155               [#coronavirus, #COVID19, #coronavirus]
# 41156                                                   []
# Name: OriginalTweet, Length: 41157, dtype: object

# %%
df['extracted_hashtags'] = df['OriginalTweet'].apply(nfx.extract_hashtags)

# %%
df[['extracted_hashtags','OriginalTweet']]
# Out:
#                                       extracted_hashtags  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3      [#COVID19france, #COVID_19, #COVID19, #coronav...
# 4      [#COVID19, #coronavirus, #CoronavirusFrance, #...
# ...                                                  ...
# 41152                                   [#NZ, #COVID-19]
# 41153                                                 []
# 41154                       [#coronavirus, #toiletpaper]
# 41155             [#coronavirus, #COVID19, #coronavirus]
# 41156                                                 []
#
#                                            OriginalTweet
# 0      @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...
# 1      advice Talk to your neighbours family to excha...
# 2      Coronavirus Australia: Woolworths to give elde...
# 3      My food stock is not the only one which is emp...
# 4      Me, ready to go at supermarket during the #COV...
# ...                                                  ...
# 41152  Airline pilots offering to stock supermarket s...
# 41153  Response to complaint not provided citing COVI...
# 41154  You know itÂs getting tough when @KameronWild...
# 41155  Is it wrong that the smell of hand sanitizer i...
# 41156  @TartiiCat Well new/used Rift S are going for ...
#
# [41157 rows x 2 columns]

# %%
##Removing Hashtags
df['clean_tweet'] = df['OriginalTweet'].apply(nfx.remove_hashtags)

# %%
df[['OriginalTweet','clean_tweet']]
# Out:
#                                            OriginalTweet  \
# 0      @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...
# 1      advice Talk to your neighbours family to excha...
# 2      Coronavirus Australia: Woolworths to give elde...
# 3      My food stock is not the only one which is emp...
# 4      Me, ready to go at supermarket during the #COV...
# ...                                                  ...
# 41152  Airline pilots offering to stock supermarket s...
# 41153  Response to complaint not provided citing COVI...
# 41154  You know itÂs getting tough when @KameronWild...
# 41155  Is it wrong that the smell of hand sanitizer i...
# 41156  @TartiiCat Well new/used Rift S are going for ...
#
#                                              clean_tweet
# 0                                              and  and
# 1      advice Talk to your neighbours family to excha...
# 2      Coronavirus Australia: Woolworths to give elde...
# 3      My food stock is not the only one which is emp...
# 4      Me ready to go at supermarket during the outbr...
# ...                                                  ...
# 41152  Airline pilots offering to stock supermarket s...
# 41153  Response to complaint not provided citing COVI...
# 41154  You know itÂs getting tough when is rationing...
# 41155  Is it wrong that the smell of hand sanitizer i...
# 41156   Well new/used Rift S are going for $70000 on ...
#
# [41157 rows x 2 columns]

# %%
#Removing Userhandles
df['clean_tweet'] = df['clean_tweet'].apply(lambda x: nfx.remove_userhandles(x))

# %%
df[['OriginalTweet','clean_tweet']]
# Out:
#                                            OriginalTweet  \
# 0      @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...
# 1      advice Talk to your neighbours family to excha...
# 2      Coronavirus Australia: Woolworths to give elde...
# 3      My food stock is not the only one which is emp...
# 4      Me, ready to go at supermarket during the #COV...
# ...                                                  ...
# 41152  Airline pilots offering to stock supermarket s...
# 41153  Response to complaint not provided citing COVI...
# 41154  You know itÂs getting tough when @KameronWild...
# 41155  Is it wrong that the smell of hand sanitizer i...
# 41156  @TartiiCat Well new/used Rift S are going for ...
#
#                                              clean_tweet
# 0                                              and  and
# 1      advice Talk to your neighbours family to excha...
# 2      Coronavirus Australia: Woolworths to give elde...
# 3      My food stock is not the only one which is emp...
# 4      Me ready to go at supermarket during the outbr...
# ...                                                  ...
# 41152  Airline pilots offering to stock supermarket s...
# 41153  Response to complaint not provided citing COVI...
# 41154  You know itÂs getting tough when is rationing...
# 41155  Is it wrong that the smell of hand sanitizer i...
# 41156   Well new/used Rift S are going for $70000 on ...
#
# [41157 rows x 2 columns]

# %%
df['clean_tweet'].iloc[15]
# Out:
# 'Lines at the grocery store have been unpredictable, but is eating out a safe alternative? \r\r\n\r\r\nFind out more about whether you should be avoiding restaurants right now:  https://t.co/9idZSis5oQ\r\r\n\r\r\n    https://t.co/ZHbh898lf6'

# %%
# Cleaning Text: Multiple WhiteSpaces
df['clean_tweet'] = df['clean_tweet'].apply(nfx.remove_multiple_spaces)

# %%
df['clean_tweet'].iloc[15]
# Out:
# 'Lines at the grocery store have been unpredictable, but is eating out a safe alternative? Find out more about whether you should be avoiding restaurants right now: https://t.co/9idZSis5oQ https://t.co/ZHbh898lf6'

# %%
# Cleaning Text : Remove urls
df['clean_tweet'] = df['clean_tweet'].apply(nfx.remove_urls)

# %%
# Cleaning Text: Punctuations
df['clean_tweet'] = df['clean_tweet'].apply(nfx.remove_puncts)

# %%
df[['OriginalTweet','clean_tweet']]
# Out:
#                                            OriginalTweet  \
# 0      @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...
# 1      advice Talk to your neighbours family to excha...
# 2      Coronavirus Australia: Woolworths to give elde...
# 3      My food stock is not the only one which is emp...
# 4      Me, ready to go at supermarket during the #COV...
# ...                                                  ...
# 41152  Airline pilots offering to stock supermarket s...
# 41153  Response to complaint not provided citing COVI...
# 41154  You know itÂs getting tough when @KameronWild...
# 41155  Is it wrong that the smell of hand sanitizer i...
# 41156  @TartiiCat Well new/used Rift S are going for ...
#
#                                              clean_tweet
# 0                                              and  and
# 1      advice Talk to your neighbours family to excha...
# 2      Coronavirus Australia: Woolworths to give elde...
# 3      My food stock is not the only one which is emp...
# 4      Me ready to go at supermarket during the outbr...
# ...                                                  ...
# 41152  Airline pilots offering to stock supermarket s...
# 41153  Response to complaint not provided citing COVI...
# 41154  You know itÂs getting tough when is rationing...
# 41155  Is it wrong that the smell of hand sanitizer i...
# 41156   Well new/used Rift S are going for $70000 on ...
#
# [41157 rows x 2 columns]

# %%
### Keyword Extraction
positive_tweet = df[df['Sentiment'] == 'Positive']['clean_tweet']
neutral_tweet = df[df['Sentiment'] == 'Neutral']['clean_tweet']
negative_tweet = df[df['Sentiment'] == 'Negative']['clean_tweet']
ext_positive_tweet =df[df['Sentiment'] == 'Extremely Positive']['clean_tweet']
ext_negative_tweet = df[df['Sentiment'] == 'Extremely Negative']['clean_tweet']

# %%
negative_tweet
# Out:
# 9        For corona preventionwe should stop to buy thi...
# 24        what is being done to ensure food and other e...
# 26       In preparation for higher demand and a potenti...
# 28       Do you see malicious price increases in NYC Th...
# 30       There Is of in the Country The more empty shel...
#                                ...
# 41127    Today at the grocery store I saw someone getti...
# 41131    In every human affliction there are gainers an...
# 41147       YÂall really shitting that much more at home
# 41149    Still shocked by the number of supermarket emp...
# 41156     Well new/used Rift S are going for $70000 on ...
# Name: clean_tweet, Length: 9917, dtype: object

# %%
# Remove Stopwords and Convert to Tokens
positive_tweet_list = positive_tweet.apply(nfx.remove_stopwords).tolist()
negative_tweet_list = negative_tweet.apply(nfx.remove_stopwords).tolist()
neutral_tweet_list = neutral_tweet.apply(nfx.remove_stopwords).tolist()

# %%
neutral_tweet_list
# Out:
# ['',
#  'supermarket today Didnt buy toilet paper',
#  'month hasnt crowding supermarkets restaurants reducing hours closing malls means entrance dependent single supermarket',
#  '13',
#  '16MAR20 Russia consumer surveillance watchdog reported case high Arctic man traveled Iran COVID19 101 observed',
#  'COVID19 coronavirus pandemic impacting consumer shopping behavior purchase decisions retail sales according Insight study',
#  'Retail store closures explode (via',
#  'Went supermarket yesterday toilet paper gone Corona virus',
#  'Breaking Story: Online clothes shopping rises people find mysterious white patches forming clothes',
#  'line outside customers wait store open morning',
#  'COVID19 restrictions sparking run cannabis stores Theyre closed Customers stocking cannabis weekend preparing retail store restrictions coming days',
#  'closed remain open emergency store Thank retail workers',
#  'thoughts impacts coronavirus food markets',
#  '4 masks medical personnel consumer purchase require onceobscure material called meltblown fabric',
#  '2K Consumers Told PYMNTS COVID19 Changed Daily Lives',
#  'ItÂ\x92s kind like saying word makes sound like word anymore people donÂ\x92t think COVID19 news BS itÂ\x92s making stores panic buy food basic necessities thereÂ\x92s left',
#  'Corona scare sends seafood prices skyrocketing Mumbai gtgt',
#  'Pausing student loan payments addition halting interest accumulation amp stopping punitive student loan collections provide needed immediate relief individuals unable work amp facing economic hardship',
#  'Â\x93at time distillery remains operation offering public tours hosting functions events retail store closed',
#  'Abilene bar feels economic impact COVID19',
#  'IÂ\x92ve online shopping past 2 days',
#  'come trending real People freaked stores canÂ\x92t food shelf stock market control sake county shut',
#  'Cleanshelf supermarket Sanitizers 19',
#  '79 (nearly 80) year old nana hasnÂ\x92t stock piled food toilet rolls Butshe stocked cupboard tubs horlicks',
#  'work supermarket store live paycheck paycheck',
#  '2K Consumers Told PYMNTS COVID19 Changed Daily Lives',
#  'Americans Stock Food COVID19 Concerns Rise thing bought list extra boxes pastahttps://tco/C0z5g5aTmj',
#  'Rack stores making efforts Washington St market drive store sales weekend $JWN',
#  'updates grocery stores shopping experiences weekend todaylet know store stock',
#  '',
#  'Casper Provides Business Update COVID19 YORK(BUSINESS WIRE)Casper Sleep Inc (Â\x93CasperÂ\x94 Â\x93CompanyÂ\x94) (NYSE: CSPR) today provided update North America retail store operations response continued spread COVID19 l',
#  'Left supermarket Right supermarket guess country press calls hysterical dysfunctional 19',
#  'kept hearing gonna travel cheap flights infect yall majority Boomers hunkered home afraid grocery store',
#  'pasta pasta sauce pizza sold grocery store Dallas Italian grandmas',
#  'Hearing multiple sources mandatory quarantine coming week citizens chance stock food amp supplies warning itÂ\x92s late',
#  'time grocery store purchase food colors rainbow Boost FOOD MEDICINE fight',
#  'Staying coronavirus Heres stock fridge pantry Staying coronavirus Heres stock fridge pantry',
#  'casualties Retail store closures explode',
#  'Couple Cleans Entire Section Store',
#  'store ransacked Thank retail workers Cant imagine craziness deal right',
#  'question happens manufactures closed plants Covid 19 shutdowns arent making food plants shut grocery stores new stock',
#  'beats classic food wheels Big Mac Meal McDonaldÂ\x92s R30 order UberEats App Promo Code: BIGMACZA TampCs Apply',
#  'donÂ\x92t think itÂ\x92s time reduce minimum online shopping basket Â£40 donÂ\x92t product stock people need think forgot single disabled people customers',
#  'DWATSON F10 selling masks high prices providing bill/receipt',
#  'Binge shopping online',
#  '5 ways coronavirus changing millennials money habits generation noi paghiamo con carta credito con (molti acquisti online)',
#  'COVID19 impacting supply chain trade workforce Check guide business leaders know Find here:',
#  'tracking effect industry step way Read blog stay tuned updates Monday Wednesday Friday',
#  'covid19 supermarket',
#  'San Francsisco mayor London Breed announce lockdown April 7 People allowed leave home midnight Tuesday doctors visits grocery store shops',
#  'Weve updated COVID19 info page including links latest DHS NDIA updates plus currently know supermarket rule changes',
#  'PYMNTS surveyed 2K consumers COVID19 changed daily lives dives results:',
#  'Supermarket workers homecare workers postal workers cleaning workers Workers services sectors find forefront societies efforts contain 19 pandemic look measures needed',
#  'monitored home Looks draconian',
#  'Supermarket scene Posting foreigners Finland group',
#  'RON 95 price diesel price public transports trains buses teksi amp e hailing service prices Malaysia year 2020',
#  'retail store owners right',
#  'came grocery store Found milk eggs gone Coronavirus real yall',
#  'tips outbreak including immunocompromised opt prepackaging fruits vegetables',
#  'COVID19 impacting supply chain trade workforce WeÂ\x92ve guide business leaders know Find here:',
#  'tech giant AlibabaÂ\x92s largest grocery store chain Beijing faring amid outbreak China checks interviews store manager',
#  'Homebound COVID19 Working cramped conditions Set Home Workstation Room | Coronavirus Consumer Reports',
#  'Today went buy groats pasta remained shelves )',
#  'online shopping way COVID19 stuff',
#  'HampM sales hit Â£5 billion prompts store closures',
#  'thought ones stock piling toilet rolls hygienic ones coughing tissue hands ones storing food buying nan young children',
#  'produce section local supermarket College St morning',
#  'Hoarders: Americans',
#  'Heres list:',
#  'prices items place order deliver doo',
#  'Consumer reporter Vicky Ngyuen qualified answer medical questions Facebook',
#  'Huh health plan broad PR push COVID19 plans saw follow industry consumer communication la retail company email list belong wonder whats',
#  'Coronavirus prompts wave store closures',
#  ':',
#  'Supermarket shelves clearing fast',
#  'Going today pick grandma hospital wear mask gloves',
#  'thought is:',
#  'online shopping Sunday true lifeline elderly disabled vulnerable customers unable store',
#  'Modeling study suggests stealth transmission SARSCoV2 high number contagious undocumented infections supported rapid geographic spread outbreak China',
#  'Bakkt Marching Summer Launch Consumer App Closing $300M Series B',
#  'Nike Urban Outfitters Armour retailers closing stores amid rapidly spreading coronavirus pandemic',
#  'WeÂ\x92ve joined amp 30 organisations recognition little relief long way thousands struggling COVID19 Consumer Action Law Centre Time amp sectors community',
#  'know lightly saute TP add bagel seasoning Trader Joes food family 4 STOCK PEOPLE',
#  'Quickly find supermarkets local store runs supplies look hospitals pharmacies coronavirus requires medical services Type location:',
#  'Student resources COVID19',
#  'Pattaya: Makro shoppers Thais foreigners stock food items',
#  'Consumers Energy suspending service shutoffs senior citizens low income customers COVID19 outbreak',
#  'NEW: Coronavirus package hits roadblocks amid GOP opposition',
#  'Cats state TV consumer rights defended China cautiously adjusts changing Covid19 situation home abroad',
#  'MC: Political Tribalism Impacts Consumer Sentiment COVID19',
#  'costs 337 cents gallon year ago Prices fell regions country saw biggest decrease 98 cents $2591',
#  'Look somebody',
#  'Urban Outfitters Nike 14 major retailers temporarily closing stores unprecedented prevent spread coronavirus',
#  'Happening country right',
#  'COMING SOON: WV AG press conference consumer issues related COVID19 outbreak WATCH:',
#  'Waiting food shopping arrive items think stock',
#  'worried food supply self isolation seriously consider nutrients need survive protein help heal easy stock store delivered door minimise spread Covid19',
#  'Piano Technicians Guild (PTG) compiled advisory explaining disinfect piano prompted continuing concern Corona Virus (COVID19) document published World Piano News website',
#  'Limit trips grocery store weeks',
#  '',
#  'Local news COVID19 impact real estate market',
#  'covid 19 got online shopping 24/7',
#  'im affraid covid19 ill spend evening crowded supermarket',
#  'items water pasta canned goods juice diapers toilet paper Married kids 5',
#  'world soon run load pussys playing Xboxs amp PlayStations whove days work self isolate constantly shopping online Minecraft city whilst drones delivery monkey spankers food',
#  'IÂ\x92ve socially distanced kitchen hurdle socially distancing unnecessary online shopping IÂ\x92m Â\x95',
#  'getting quarantined shoukd stock food',
#  'Soooo retail workers close 8 people let store need answers',
#  'work overnight retail major sporting goods store find mind boggling woman 70s lives 90 year old mother guy GF works ER Come people',
#  'Realizing online shopping businesses email addresses sending closures COVID19 indicate workers getting paid',
#  'Microsoft announced tonight close Microsoft Store retail locations COVID 19 outbreak',
#  'Oil Prices Exchange Markets Machine Learning Network Technology New World loading',
#  'COVID19 keeps hitting economy Regina Food Bank putting financial donations deliver food hampers people need',
#  'People crowding doors supermarket Saint Denis day announced tightening travel restrictions',
#  'face mother asks grocery store 15 minutes IÂ\x92ve ordered pickup service',
#  'Im proud country El Salvador n precautions government everyday people taking prevent Covid19 Pregnant women seniors 60+ stay home n paid sick leave borders closed prices basic goods monitored',
#  'works supermarket right now:',
#  'food beverage services allowed provide aways operators need platform deliver food walk customers',
#  '1st Wave China 2nd Wave Local Mass Gathering 3rd Wave Supermarket Balik Kampung Transport Police Station Gathering 4th Wave Sampai Kampung Gathering',
#  'mum called told want stock food weed bc COVID 19 getting',
#  'youÂ\x92re people excessively stocked food COVID19 panic donate canÂ\x92t/wonÂ\x92t use shelters food banks instead letting waste',
#  'Dubai Cheaper Live',
#  'possible virus given cashier supermarket Asking real question',
#  'Steep rise prices platform ticket prevent unnecessary crowding stations',
#  'delivery hiring 100000 new distribution workers online shopping surge caused',
#  'fam decided change house supermarket',
#  'Im grocery store purse disposable gloves',
#  'Alright Swiss government called emergency status unnecessary stores closed disinfect hands enter supermarket doctor donÂ\x92t want',
#  'waiving change fees April flights flight want change miraculously expensive original flight end pay flight want change prices rigged',
#  'wife got grocery Union St Bangor opened 7am today line door manager handing individual rolls TP 2 large packs store',
#  'Mask sanitizers sold sky high prices Instead helping people time crisis sellers trying profit request central state government necessary action',
#  'Supply flowing machines running product way shelf says Doug Baker FMI CBS News',
#  'pm Boris Johnson says self isolate seek help pensioners risk pensioners online shopping wold essential locals near future delivery slot SAINSBURYS supermarket normal times shop',
#  'socks pants jocks wearing particular day Tonight 9pm',
#  'experiencing high volumes enquiries travel event cancellations related COVID19 (coronavirus) Read advice consumers latest consumer rights travel event cancellations relating COVID19',
#  'seeing TV advertising food stock need reminder',
#  'Let know Cletus memes2riches (',
#  'Turner joins grocery chain representatives update public supplies store hours',
#  'Lav Aggarwal Joint Secretary Union Health Ministry: ICMR (Indian Council Medical Research) strongly appealed private laboratories offer COVID19 diagnosis cost',
#  'Gas prices set tumble Tomorrow prices pump 779 cents litre says story',
#  'wife got laid yesterday small retail store works got walloped walkin business vanishing COVID19 long thinking taking EI process claims right',
#  'modify amid',
#  'explode',
#  'Im enjoying describing trip supermarket need Ill panic buying returning usual half dozen items',
#  'Ministry fixed food prices order prevent markets hiking outbreak',
#  'Une centaine de personnes se pressent aux portes dÂ\x92un supermarchÃ© Ã SaintDenis en banlieue parisienne au lendemain de lÂ\x92annonce du PrÃ©sident Macron renforÃ§ant les restrictions de dÃ©placement face au',
#  'time America collapse rough unsung heroes grow food ship goods stock shelves pump oil staff hospitals fill pipes water fires police streets lights',
#  'Online grocery shopping trial',
#  'Closures online grocery shopping elderlyonly shopping hours ways businesses trying prevent spread coronavirus',
#  'People stand queue enter supermarket outbreak coronavirus disease (COVID19) El Masnou north Barcelona Spain March 17 2020 REUTERS/ Albert Gea reuters',
#  'downturn prices short term nature months years unlikely affect negotiations long term contracts average 10 years',
#  'essential retail store',
#  'local grocery store Zoom',
#  'TIME STEP',
#  'went vote sprayed Lysol went grocery store man coughed',
#  'glad local supermarket reduced opening hours Gives time poor staff fill shelves',
#  'Stocked supplies today: Grocery Pet store Gas station Liquor store catch Nintendo magazines home projects',
#  'cough grocery store',
#  'Youre grocery store buy following family week getting',
#  'program leave grocery items marked WIC logo families donÂ\x92t leave store handed donÂ\x92t substitute',
#  'Gov Brad Little conference right now: Dont hoard think neighbors grocery store',
#  'Lockdownour mind matter',
#  'Ah businesses conscience Unlike keeping open grocery store gaming areas SENIOR CITIZENS tending machines',
#  'Breaking News: Microsoft closing retail stores notice Check OnMSFT',
#  'Weve got house',
#  'Yesterday asked pharmacies constituency hiking prices essential goods appalled learn practices hope expect shops large small acting responsibly',
#  'Atlantabased furniture store chain Havertys said Tuesday response COVID19 outbreak temporarily close retail locations beginning March 19 April 2',
#  'Rwandans opt online shopping amidst COVID19 pandemic',
#  'grocery store runs bread peanut butter',
#  'retail clothing company work 20% price items encourage people store buy fucking madness need close essential retail stores',
#  'Look whatÂ\x92s holding iPadmy toilet rolland multivitamins canÂ\x92t buy food thereÂ\x92s supermarket',
#  'people total legends: line NHS staff Carers Supermarket shop workers GP Surgery receptionists Epedimiologists',
#  'Malaysia jam itÂ\x92s supermarket streets',
#  '15 retailers businesses added closure list today (Nearly offer online shopping)',
#  'long supermarket home deliveries follow suit',
#  'Trump days ago',
#  'NIELSEN CONSUMER BEHAVIOR THRESHOLDS COVID19 CONCERN',
#  'Malaysia key source staples Singapore imports 90 food',
#  '25 people allowed grocery store time Trying grocery store line told patient minutes let 25 people store',
#  'Brace UFC supermarket edition coming',
#  'shelves little neighborhood grocery store days ago @ Omaha Old Market',
#  'curb crowds railways increases prices platform ticket',
#  'Esto es un Carrefour antes de abrir Â¡Â¡Â¡Viva las personas',
#  'globe outbreak changing way people work learn massive scale likely result Â\x93changed worldÂ\x94 including online education online shopping public health investments etc /',
#  'Amazon looking hire 100000 people crush online orders coronavirus spreads keeps people home shopping online',
#  'Imagining hour grocery store hoursThe Senior Citizen 500',
#  'National Retail Federation advocates behalf merchants asks governments advance notice ordering store closures',
#  'Interviewed Bill Kelly podcast Retail discussion starts 24:30',
#  'food supply chains effected wondering amp supermarkets informed general public availability stock basic bread milk toilet paper etc confirm enoug',
#  'Unprecedented attempt contain outbreak thousands stores/other businesses closing doors customers Grocery stores amp staying amp limiting hours cleaning/ restocking store shelves',
#  'Wash hands amp touch face mindful Keys Cell phones ATM amp grocery store PIN pads Paper money Door handles Handrails Elevator buttons Communal surfaces Gym weights',
#  'updates visit',
#  'Sephora says closing stores Canada March 17 April 3 list closures:',
#  'offering deliveries tonightSo14 so15 so16 so17 so18 so19 minimum spend Â£25 usual menu prices delivery fee Starting 530pm ring order',
#  'Shoppers Drug Mart hikes prices amid coronavirus pandemic',
#  'Follow turn notifications updates',
#  'Home Depot grocery storekeep walking pull red lightdonÂ\x92t roll window wave',
#  'Notes Went grocery store 6:30 small piles newly delivered toilet paper shelves entire aisle bare Sign said Limit 3 bought 1',
#  'walk supermarket 3rd day row canÂ\x92t find bog roll',
#  'work organization provides Thursday unable stock distributers (stock newly expired castoff) largely food bank closed word',
#  'online shopping hoard includes spice rack floor lamp 2x toilet brushes Wbu',
#  'Consumers looking online shopping',
#  'Heres list temporary store closings',
#  'New Interactive Consumer Spending Report: COVID19 Pandemic Impacts Consumer Economic Index Â\x93Despite circumstances retail spending expected continue 30 daysÂ Â\x94',
#  'word Latin humanitas human nature kindnessÂ\x94 increasing purchase prices exploiting need moment reflex times need',
#  'cool company policy Sephora closing stores moving corporate work home continue pay retail workers shifts scheduled going working home',
#  'Seeing bare aisles grocery store lately Read article learn whats essential buy pandemic',
#  'closures explode',
#  'father son dressed hazmat shopping grocery store yesterday video',
#  'stock disinfectant sold Check laundry section grocery store',
#  'La fin du monde',
#  'country needs band togetherand tip grocery store workers massive amounts money',
#  'Skip grocery store Misfits Market Right 50% order promo code COOKWMEFE8VLT',
#  'grocery store employees gas station attendants deserve living wage',
#  'Find consumer consumption changing means',
#  'recruit 100000 extra workers cope coronavirusinduced online shopping surge retailer plans focus providing jobs hospitality service industry workers work prompts shutdowns:',
#  'exclusive conversation Construction Week CEO Dalma Capital Zachary Cefaratti talks effects consumer behaviour demand |',
#  'Probably people stock piled food Uber deliver McDonaldÂ\x92s food use people vaccination trials',
#  'China consumer impact COVID19 $BABA $JD $PDD $TCEHY $TCOM $WYNN $LVS $MLCO $IQ $BILI $YUMC DM email craig data',
#  'buy grocery store pandemic CNN',
#  'Online shopping',
#  'Lineup grocery store Spain 15 people time rest wait outside 1 meter apart',
#  'WhereÂ\x92s sanitizer',
#  'grocery store gas station somebody sneezes coughs',
#  'Grocery store workers break',
#  'Probably buying toilet paper',
#  'People buying 2 lots 24 pack toilet rolls Makes wounder arseholes people think',
#  'infinite line supermarket doors total confinement long remain open',
#  'online shopping creaking time prioritise elderly customers',
#  'stocking $10 TrinitySSWellness',
#  'believed going economy money earn obvious function garbage workers farmers fruit pickers grocery store cashiers compensated',
#  'Heading supermarket country lock',
#  'read account physical contact cium tangan covid 19 positive person went packed supermarket day bad experience online shopping GP said alright Yeah panic buy summore',
#  'IÂ\x92m speechless act Brooklyn bodega offering 1020% food products respect notice donÂ\x92t burn bridges customers trying quick buck price gouging bite ass',
#  'opening 8am closing 8pm online shopping Hospital schedule 6:30am start gt8pm finish Hmmm',
#  'timely information',
#  'People hoarding masks selling inflated prices report sellers police',
#  'Need tax return online shopping',
#  'Â\x93last food remainingÂ\x94 bracket pick grocery store monitor shelves',
#  'twitter people thanking healthcare responders thanking grocery store workers stores restocking making sure need difficult times Thank grocery workers',
#  'Hit Dm buy sanitizers actual prices',
#  'Tomahawk ribeye quarantine food stock',
#  'spooks commodity market Heres prices look',
#  'wilding rn',
#  'ima makin food yÂ\x92all wanna grocery store',
#  'Check Keeping Track States Shutting DineIn Service COVID19',
#  'Maybe people buying TP supermarket try toilet paper',
#  'Current situation local grocery store',
#  'necessary people selfisolating means shopping urgently looking establishing online shopping/delivery complete lockdown ordered',
#  'Fijian Competition Consumer Commission carrying assessment supply chain More:',
#  'Illinois supermarket shut dozen people told quarantine customer coronavirus entered store',
#  'Nearly 40 percent states announced statewide closures dining areas restaurants',
#  'largest cities America closed restaurant dining areas',
#  'Caught short shopping team checked stocks toilet roll online published list site found sale:',
#  'Coronavirus Tips: Stock COVID19 [LIST]',
#  '9 Online Grocery Shopping Stores Klang Valley Deliver Doorstep COVID 19 Outbreak',
#  'thought leadership consumer changes airlines govt gives industry bail Ive heard congressional staff musing idea',
#  'Went grocery store today',
#  'Guess head grocery store find',
#  'Day 2 called grocery store busy going grab necessities Apparently frozen pizza necessity needed thing abundance',
#  'scored haul grocery store tonight @ Frisco Texas',
#  'cancellation refund policy line Section 17 Consumer Protection Act Government policy COVID19',
#  'grocery store Pound Ridge NY felt shoppersÂ\x92 rush taken yesterday',
#  'published Waking Coronavirus Businesses entrepreneurs economy going Â\x97 online',
#  'canÂ\x92t find amp tomorrow IÂ\x92ll try trading',
#  'Economic investment implications discussed note clients week Sharmin MossavarRahmani head Investment Strategy Group Consumer Investment Management Division Goldman Sachs Read here:',
#  'COVID19 Outbreak Forces VF PVH Gap Shutter Global Retail Doors Â\x96 Sourcing Journal',
#  'donÂ\x92t going amp amp',
#  'interesting article Economist collapse number Goverments dramatic fall oil commodity prices regimes depend',
#  'supermarket tried distance que woman walks stands right asked watches news proceeded ask step',
#  'Supermarket shelves East London emptying soon filled crowds Covid19 danger alarming terms food security Prices doubling local corner shops wholesalers SainsburyÂ\x92s Whitechapel',
#  'Seattle schools continue provide meals thousands receive 800 grocery store vouchers funded sugary drink tax',
#  'think charge Compact Prices (especially people premium Sport) canÂ\x92t paying repeats weekend',
#  'Expert market commentary Nate Donnay Director Dairy Market Insight INTL FCStone Financial Inc FCM Division quoted',
#  'going supermarket',
#  'said Â\x93the end timesÂ\x94 thought weÂ\x92d living trivial lives penultimate moment demise weÂ\x92d realizeÂ\x97weÂ\x92d spent days grocery store buying toilet paper',
#  'stocking let know comments',
#  'Day Luzonwide enhanced community quarantine prevent spread COVID19 9:30am line supermarket counter Los BaÃ±os Laguna Social distancing barely observed shoppers stock supplies |',
#  'Day Luzonwide enhanced community quarantine prevent spread COVID19 Crowd 10:30am supermarket Los BaÃ±os Laguna Shoppers barely observe social distancing stock supplies |',
#  'saying Â\x93If xyz canÂ\x92t voteÂ\x94 (go grocery store etc) doesnÂ\x92t mean thing',
#  'Business Europe',
#  'ultimate flex today walking grocery store wearing 3M N95 mask holding 24 pack Charmin toilet paper',
#  'Running supermarket public gathering stores essentials needed COVID19 bay need sanitization products Order online WeÂ\x92ll rest',
#  'Bravo right thing customers employees Businesses notice',
#  'ItÂ\x92s interesting people flat ignoring limits ThereÂ\x92s limit 2 Susan',
#  'Scientists discovered virus carried Supermarket toilet paper supplies',
#  'ZÃ¡sah policie proti spekulantm rouÂ\x9akami Na mj popud hejtman Ã\x9asteckÃ©ho kraje spoluprÃ¡ci podle krizovÃ©ho zÃ¡kona zajistil tÃ©m 700 tisrouÂ\x9aek od firmy kterÃ¡ je mla dodat na zdravotnÃ\xadkm ale na poslednÃ\xad chvÃ\xadli se snaÂ\x9eila navyÂ\x9aovat cenu',
#  'brother struggling change routine covid19 going gym supermarket day etc sudden usually needs weeks cope change suggestions help',
#  'spike online shopping',
#  'Omgggg sent emergency alert COVID19 everyones phones went supermarket (Yes Im necessities cus missed weekend)',
#  'local grocery store',
#  'Im joining conference shortly Food City CEO Steve Smith regards COVID19 affecting supermarket industry',
#  'grocery store rubbing alcohol wipes moment',
#  'cough grocery store allergies public look',
#  'Went grocery store today water sold Dasani shelves plenty Encouraging know thing gotten Â\x93Dasani waterÂ\x94 bad',
#  'process online shopping mean youÂ\x92re relying lot people wash hands',
#  'fact canÂ\x92t online booking food 2021 daughter taking food shopping tomorrow morning suppose walk shop 2 meters apart comply social distancing stay 2 meters apart car',
#  'toilet paper isle grocery store work',
#  'Unreal planned grocery store thing morning deliveries supposed happen overnight deliveries huge lines people NOPE',
#  'grocery store people creep 6 ft rule',
#  'Sainsbury: elderly hour supermarket trading Covid19 Sign Petition',
#  'Petition Â· elderly hour supermarket trading Covid19 Â·',
#  'Adjusted opening hours Phone calls Video conferences Working home Shopping online Different means business Come nation staying apart',
#  'store point litterally left shelf dont truck 2 days soo',
#  'Tips grocery shopping works grocery store (not me)',
#  'Shopping set change says agree people rarely shop online lot amp government cash good',
#  'ports terminals shuttered fewer ships loaded consumer goods parts American factories set sail China exports poultry oranges piling docks',
#  'went grocery store cashier A) elderly B) oxygen machine real life',
#  'headed grocery store',
#  'wondering Hotels operating allowed operate sharing thoughts: think risky stockpiling supermarket groceries got affected touched u',
#  'Watch story consider shopping long trucks rolling food Remember purchased store online delivered truck point',
#  'stock reassurance FMF Foods Ltd managing director Ram Bajekal countries battle deadly coronavirus disease',
#  'people bought 45L soap left supermarket realise need wash hands away virus',
#  'wondered watching Legend raided houses food grocery store know',
#  'state makes announcement shutting liquor stores pa',
#  'excise hike petroleum prices understandable given spread temporary step',
#  'government announced implementation movement control order contain spread Covid19 beginning tomorrow early shoppers began queuing outside Giant hypermarket waiting shop daily essentials',
#  'find Purell cant survey shows ~50% shoppers impacted outofstocks',
#  'wants listen',
#  'Went grocery store Friday night buying corned beef',
#  'Watch food prices',
#  'Im supermarket cough 4 rolls toilet paper trolly reason bought',
#  'buying Im wondering people replacements online shopping Baking paper House plants',
#  'GROCERY STORE EMPLOYEES',
#  'line inside JoeVs grocery store capacity',
#  'Shelves second grocery store IÂ\x92ve visited week',
#  'associates diagnosed Colorado Washington',
#  'Restaurants amp Supermarkets offer washing hands sanitizers long Covid19 restaurant amp supermarket infect',
#  'businesses looking resources find updates EOHED website team updating site additional tools available Continue following updates :',
#  'concerns new national retailers adjusting hours',
#  'grocery store Hear stories latest Episode 221 available (link bio) featuring shopping stories KY reports west coast PlusÂ',
#  'message manager day retail store close 2 weeks',
#  'Online shopping paid',
#  'Prices platform tickets 12 railway stations including increased 5 times 10 50 avoid extra people rail premises IE',
#  'grocery store today',
#  'COVID19 Impacting',
#  'Tracking response',
#  '50 major retailers temporarily closing stores unprecedented prevent spread',
#  'Landin Coronavirus priorities didnt stock food TP Liquor',
#  'wanted Supermarket Sweep fucking applied',
#  'Chinas Egrocery Booms Consumer Diet Shifts Epidemic',
#  'getting logic suspending online deliveries Australia Doesnt mean people shopping supermarkets spreading people cant supermarkets supposed',
#  'needs',
#  'Time start ripping grocery store especially stockers checkout clerks',
#  'red light eventually turns green',
#  'Donald Trump Raider Supermarket response',
#  'UPDATED: Commissioner Nikki Fried Activates ChildrenÂ\x92s Meals Website COVID19 School Closures / 2020 Press Releases / Press Releases / News amp Events / Home Florida Department Agriculture amp Consumer Services',
#  'driving Compton 55th Street South Central LA decided ask prices lady said $10 packages $20 package',
#  'knew concern wasnt went supermarket earlier today hit Saw women 10x 12 pack toilet paper took ounce hey need',
#  'Exactly going need stock food amp medical supplies : Saudi Arabia says foodstuff goods abundant 3700 hypermarkets',
#  'Storefront closed asked shop online orders shipped',
#  'supermarket Miami hour opening',
#  'Hi offering assistance negatively impacted COVID19 learn here:',
#  'Retail store closures rise coronavirus',
#  'went grocery store today find pasta eliminated live',
#  'thought waiting line grocery store Mike moved weekend donÂ\x92t ton food left',
#  'ThereÂ\x92s donÂ\x92t know coronavirus questions long COVID19 live surfaces Consumer investigator breaks new study gives preliminary answers',
#  'posting days quarantine work grocery store shut job',
#  'Read new series update blogs learn global pandemic affecting shoppers search buy online New posts M/W/F',
#  'Shopping malls shutting doors beginning tomorrow',
#  'Coronavirus UK: Supermarket deliveries weeks',
#  'COVID19 Supermarket Sweep',
#  'Walking supermarket amp need gone',
#  'correct balance hoarding limiting trips grocery store',
#  'youÂ\x92re home try experimenting online content Try recording house vlog video Upload video trying new hair style Screen Record online shopping experiences content',
#  'light COVID19 store hours beginning Wednesday March 18 10 6 pm 18 retail locations',
#  'Brits running shops stock food Americans running shops buy guns wondered far apart Nations',
#  'companies CombinatorÂ\x92s W20 Demo Day II: Consumer Companies CombinatorÂ\x92s Demo Day bit different time concerns grew spread COVID19 Combinator shifted event format away twoday gathe',
#  'San Francisco Line grocery store DoesnÂ\x92t open 12pm Eastern day Â\x93donÂ\x92t stand closer 6 feet apartÂ\x94',
#  'went grocery store amp left governor Bob Evans guess',
#  'rundown supermarket',
#  'pointing local businesses massive local website fixed prices amp minutes delivery beat',
#  'COVID19 Retail Store Closures',
#  'Grocery store neighborhood',
#  'Pandemic Chopped: Im looking forward photos culinary art people left grocery store 2 eggs frozen waffles frozen veggie medley rehydrated turkey jerky',
#  'tracker retail stores closed pandemic',
#  '99% corporatespeak emails COVID19 *scroll skim delete* 5 seconds Read thing ItÂ\x92s professional hits consumer concern understands target audience',
#  'Paid Costco membership fee find toiletries sold got 5lb box matzah Passover',
#  'People running away quarantine hiking prices hoarding masks sanitisers amp essentials absolute scum earth 2020 Identify remember bring',
#  'seen men supermarket time Australia',
#  'Lets consider citizens says testing prices',
#  'closing crowded places order closure TV Studios responsible spread panic caused created artificial scarcity medicine food amp sanitiz',
#  'Kroger Co store associates diagnosed coronavirus',
#  'Wassup Covid19 sales alot retail store sales',
#  'Trade Secretary Lopez: online shopping nonessential products allowed Live 1350 Band',
#  'THREAD/ fight spread government advised people nonessential travel BritainÂ\x92s train companies working help customers plans changed booking ticket Details',
#  'local Tesco 17:00 17 Mar 2020 took 13 images empy shelves toilet/kitchen roll pasta/noodles cereal tea posted: beer bin liners lots tinned goods cat food lager potatoes',
#  'got home 4 hours stocking grocery store shelves local store work parttime slammed entire time Heres saw:',
#  'People shopping shop house grocery store isnÂ\x92t hang place ainÂ\x92t got need',
#  'Sainsbury: elderly hour supermarket trading Covid19',
#  'Stock Product says Ministry Details here:',
#  'Store Mall Closings Canada',
#  'Financialy speaking measures taken consumer bills economic issue Corona Virus afford',
#  'WWD COVID19 Retail Store Closures',
#  '',
#  'closed retail sales social distancing measures',
#  'monitored rapidly evolving COVID19 situation decision close retail store locations starting Wednesday March 18 weeks situation everchanging plans change posted 1/6',
#  'Me: (not panicking making food crafting reading watching Doctor: (Three days ago) Stock WHO: (Just now) Ibuprofen enable Me: shit (Starts episode',
#  'Co store associates diagnosed',
#  'Seattle offer $800 grocery store vouchers 6000 families',
#  'designated days week persons 55+ suggest Tuesday Friday early early store opening',
#  'Found toilet paper local grocery store cause people dont shop',
#  'Consumer Buying Behaviours COVID19 situation',
#  'bigname franchises retailers shut doors mitigate spread midAtlantic chain plans continue gas grocery storeesque services essential pandemic',
#  'Shopping online Switzerland : queue enter site = 30 minutes delivery date : April 1st',
#  'Hear America Instead lining supermarket messing social distancing stores handed tickets store entry times wait cars',
#  'COVID19 Impacting Online Shopping Behavior | Adobe Blog',
#  'Voted morning polling place 10 minutes Went local farm store waited hour line buy eggs grocery stores',
#  'COVID19: stores Oman commercial complexes close food consumer catering shops clinics pharmacies optical shops',
#  'major continues fall Monday fellÂ $20s',
#  '72 hours plasticand cardboard longer think Id think stay away tunnels slides',
#  'AHHHH COVID 19 STAY ROOM STOCK FOOD POSSIBLE',
#  'Tales grocery store Ch 4 Mutiny Bounty',
#  'visited service centre found Apple store open read notification Apple till 27 march 2020 Retail Store remain closedits apple Store',
#  'poor retail sales numbers today good day sell Costco Stock currently 304 rate $270 headwinds Customers bought lot food essential items mean continue buy excess supplies $COST',
#  'People implement grocery store pick and/or delivery instead going grocery stores',
#  'UK retail industry stepping response COVID19 stores choosing close noticed store closures high street town city Let know',
#  'People wearing face masks following outbreak ( walk past retail store',
#  'Face COVID19 Pandemic Steelworkers Humanity Fund Contributes $220000 Food Banks Canada',
#  'Seth Mendelson talks store managers clerks new blog series retail managing issues coronavirus pandemic',
#  'Seen woman supermarket wearing gloves wiping groceries places trolley delves bag answer mobile holds face wearing gloves',
#  'new banger town Amazingly cheap prices',
#  'Saw today Tesco grocery store near London',
#  'Online shopping toilet roll driven pour glass wine 948373rd night row',
#  'Seattle offer $800 grocery store vouchers 6000 families Checking Corona Live Updates',
#  'Hi Kate weÂ\x92ve announced offers consumer small business customers unprecedented times continue provide updates business people policies customers Telstra E',
#  'Protecting consumers amid pandemic',
#  '3 3 63',
#  'Going store barely able stock food unable find toilet paper preview permanent lives Bernie Sanders elected virus showed',
#  'COVID19 causes business boom Ithacabased online grocery platform Rosie',
#  'Hyderabad: Consumer forum adjourns month',
#  'Retail store announced shutting restaurants store reduced trading hours point',
#  'time crisis Sun delivered FREE home 12 weeks',
#  'retail sales 05% February 43% (YoY) indicating consumer spending major driver economy trending prior COVID19',
#  'time doctors grocery store workers janitors etc line paid society',
#  'AG Paxton Reminds Aware Cyber (',
#  'Bulletin 20201: Coverage COVID19',
#  'app VLSIs Coronavirus Watch Week+5: weekÂ\x92s Sales 18% units 19% 5year TMA week+5 pandemic1 Prices crawled 2%',
#  'Â\x93I expect horrible pandemic getting sick pointÂ\x94 supermarket employee explains itÂ\x92s like coronavirus trenches',
#  '88yearold mother took trouble write request visit Christian holiday Easter work supermarket shes afraid infect COVID19',
#  'effort prevent spread COVID19 virus Department Enterprise Services Surplus Operations retail store closed public notice',
#  'Hot Topic stores closed period time health concerns time store employees paid',
#  'Deputies said caller asking personal information guise checking eligible coronavirus test kit',
#  'COVID19 news permeated media noticeable behavioral shifts taken hold',
#  'told meat department local grocery store told raise prices hamburger rush',
#  'waive late fees terminate residential small business customerÂ\x92s service financial circumstances associated COVID19 suspending data usage limits consumer customers time period C',
#  'went grocery store morning line outside door letting groups 25 50 store',
#  'Grocery Store pump gas',
#  'buddy Las Vegas grocery store',
#  'waiting monatary donations yelled Bars/Restaurants open wanted closed bills need paid food needs bought essentials stock Pony cash got wanted',
#  'consumer step home Â\x96 stay',
#  'cash register constant contact 100+ people day 2ft away faces grocery store spread home families forth',
#  'list prices alcoholic antiseptics order interim measures high price days Source',
#  'grocery store union closing Â\x93for weeksÂ\x94 staying open',
#  'run toilet paper',
#  'grocery store $8 spaghetti pasta',
#  'time isolating bubonic plague mark doors black cross today use door signal people stay awaybut shopping bags purchased groceries online retailers',
#  'hit 99 cents states supplies expert says',
#  'Went grocery store 9AM didnÂ\x92t needed',
#  'Joining hands UAEs efforts contain spread coronavirus (COVID19) amp considering wellbeing mall visitors amp community general prayer areas cinemas stay closed notice Lulu Hypermarket amp stores operating routine',
#  'Covid19 Store Update: Temporary store closures mount | Chain Store Age',
#  'maintain social distancing supermarket',
#  'local supermarket stock shampoos soap hand sanitizer stock alcohol',
#  'SU Students happening ppl serve food day:',
#  'world priorities',
#  'Grocery store morning',
#  'people stock food toilet paper quarantine apparently stocked drugs',
#  'help online shopping refrain buying non essential items Covid19 pandemic local delivery service providers working 11 hour days global crisis new patio set curtains wait months Susan',
#  'got online shopping 24/7',
#  'biggest mall area closed store work open',
#  '50 people max gathering store workers swamped',
#  'felt scored refried beans grocery store today',
#  'Covid 19 shutdown Govt says online shopping delivery non food necessities count essential services',
#  'IKEA closing U stores COVID 19 continue offering online shopping',
#  'drive store business booming',
#  'charged $7 delivery place 6 miles away Additionally menu prices 3x regular price things seriously charging people time need Thank whatÂ\x92s right',
#  'concerned traces COVID 19 packages delivered Experts weigh',
#  'IKEA closing stores COVID19 continue offering online shopping',
#  'wait 3 weeks food delivery Im self isolating dont think current stock food carry far',
#  'Update Belgium Lockdown 30 mins ago allowed animal food pharmacy post office types shops open Fines 4000 amp 3 months jail Yesterday supermarket fruits amp vegetables',
#  'Prices plunge pumpsagain',
#  'city Los Angeles providing 5000 masks grocery store clerks 10 thousand masks responders',
#  'include stealing people need want need know people afraid know survival instinct survive Let decent thing Let share',
#  'think read disappointing headline long time People better pandemic local food bank',
#  'wonder long therell run banks cash locusts stripping supermarket shelves bare',
#  'kineticsquirrel: asked supermarket toilet paper amidst COVID19 outbreak',
#  'Line supermarket Italy distance people lengthy queue',
#  'Govt says online shopping delivery non food necessities count essential services rodahidup benjamin aruna soh',
#  'MENTION work grocery store probably little stores thats open moment lot different people everyday touch lot stuff feel like Im higher risk COVID19 Im like UGH',
#  'work UK supermarkets besieged customers',
#  'Opportunistic increases soap prices 10 amp 25 India News',
#  'snapshot going effect job market forever quarterly planning today client major consumer electronics firm heard 1',
#  'enters lockdown noon today line outside local grocery store',
#  'Queensland supermarkets green light restock 247 COVID19 cases leap',
#  'person irony able find hot dog amp hamburger buns meat grocery store',
#  'shopping online toilet paper amp scroll little gem',
#  'Queensland supermarkets green light restock 247 COVID19 cases leap',
#  'prices stay low predicted 6 months definitely recession COVID19 causing low demands oil oil powers ramping production Simple economics free',
#  'Found Facebook: fact grocery drug store food preparation workers considered Â\x93essentialÂ\x94 workforce shut proves folks deserve living wage',
#  'Pix: Supermarket Long Lines Melbourne',
#  'City Fresno considers shelterinplace order response COVID19: LIVE',
#  'long virus New study looks survival time germ causes COVID19 outside living body',
#  'Covid19 VIRUS changes consumer behaviour',
#  'apparently tomorrow allowed supermarket/pharmacy/work(if needed)',
#  '$KOPN COVID19 spawned mass market VR government consumer market new world post Coronavirus different People home need VR technology mental health productivity / remote work $KOPN BOE VR',
#  'Covid19 concerns ATKÂ\x92s consumer services staff activities online Specialists available talk needs email phone Skype Zoom variety online options 8005263648 online',
#  'Australian supermarket shopping hour elderly disabled vanLoon',
#  'Scammers prey people difficult situations contacted offering recover money event holiday look signs potential',
#  'look shoppers lining outside local grocery store waiting search supplies',
#  'eMarketer Podcast: Europe Coping COVID19 UK Digital Tax Social Media Marketing eMarketer',
#  'COVID19Related Consumer Behavior Shifts Stay',
#  'Executive Chairman discussing impact markets oil prices Watch:',
#  'Reliance Industries Chairman Mukesh Ambani longer AsiaÂ\x92s richest man relinquishing title Jack oil prices collapsed global stocks',
#  'Europe chemicals prices stocks sink stimulus afterglow fades',
#  'LISTEN: quake hit SmithÂ\x92s grocery store Bountiful elderly shoppers store new Covid 19 hours accommodations evacuate:',
#  'thread pretty small budget cant afford stockpile food essentials panic buying shelves human stop',
#  'COVID19s Business Consumer Impact Europe',
#  'closes doors weeks',
#  '13thno online shopping deliveries April 1st wife 2 year old ok food minute suggest',
#  'Virus: 10 Consumer Trends Post World',
#  'COVID 19 Impacting Online Shopping Behavior',
#  'man wears protective mask carrying toilet paper outside supermarket Brussels Belgium Mar 18 2020',
#  'youÂ\x92re meaning masks prevent *getting* materials specific available average consumer :(',
#  'Petition COVID19 edition Supermarket Sweep',
#  'Key consumer behavior thresholds amp impact retail',
#  'weekly shop 7am queueing 8am able need country cnuts',
#  'Covid19 impact vs Seattle',
#  'Looking check direct deposit gov Read',
#  'Went grocery store flour gone flour hoarders gonna baking bread',
#  'Right telephone list emergency numbers think right areas Like food deliveries ring petrol stock companies case',
#  'asked posts robberies grocery store parking lots subjects offering test going door door neighborhoods time received reports incidents locally',
#  'Note Area 51 fireworks COVID19 Unfortunately fireworks retailers considered nonessential businesses retail closed notice Wholesale customers contact store info 9am6pm Demo day scheduled planned April 25th',
#  'hrs AIA week be: Trenton: 3/183/20 10am12pm supplies Princeton: 3/18 amp 3/19 1:304pm supplies Closed 3/20 Prepacked grocery bags available outside pantries',
#  'Im officially calling BS movies Ive seen grocery store pandemic Toilet paper currency Im calling',
#  'Entering grocery store city lockdown',
#  'massive injection liquidity coupled likely long lasting damage consumer confidence Â\x93stagflationÂ\x94',
#  'VTA urged patience transport operators work overtime respond record consumer demand prompted salute tremendous efforts transport supermarket workers challenging times',
#  'Grocery store employees ask toilet paper',
#  'Price gouging past week communities North America react COVID19',
#  'Teleworking outbreak youÂ\x92re getting workathome systems set tips protecting devices personal information Read More:',
#  'Checks government',
#  'closing stores continue offering online shopping',
#  'virus concerns grow heres list shop groceries',
#  'Warby Parker stores closed March 27: Retail employees continue paid online store remains open Home TryOn program Virtual TryOn tool cust serv email/text/chat continues',
#  'COVID19 Coronavirus New Zealand supermarket shelves 17 March 2020',
#  'Council urging governor reconsider closing liquor stores',
#  'way grocery store',
#  'demand animals food skins entertainment increases risks infectious diseases',
#  'Oil crashes 14% today',
#  'Gas prices hit 99 cents states coronavirus supplies expert says |',
#  'time open shop doors Supermarket Sweep',
#  'thisladies gentlemen citizens UK spreading Caribbean',
#  'government announced schools close Monday',
#  'Price gouging Â\x96 price gauging opinions companies',
#  'Supermarkets adapt deal Consumer habits changing store asked customers bring children shopping',
#  'Current dont exist dating 1953 66',
#  'state Arizona 24hour helpline seniors unable access groceries: 6022644357',
#  'PSA: local grocery store adjusting hours Seniors Let neighbors know social media know telling',
#  'food toilet paper stock gotta sing feelings 19',
#  'assisting customers Government Center West (GCW) completing licensing permitting needs online reduce spread COVID19 GCW Virtual Operations County information COVID19:',
#  'Vault Health launches consumer mens health service $30M Series suspends inperson visits COVID19',
#  'largest grocery chain China tech giant Alibaba faring amid outbreak checks interviews store manager Beijing',
#  'Cases rise India govt says monitoring soap prices Catch updates',
#  'Read Learning IGA Chinas Coronavirus Experience Grocery',
#  'Scammers prey people difficult situations contacted offering recover money event holiday look signs potential',
#  'COVID19 Changed Consumers Daily Lives',
#  'Consumer Protection Act: Cancellations Bookings Reservations Context COVID19 Travel Bans Restrictions',
#  'Work affecting business Weigh short poll',
#  'donÂ\x92t think',
#  'Tuesday afternoon Calgarybased airline identified 14 COVID19 cases involving passengers',
#  'Final version graphic: told today implement moratorium shutoffs utilities including ordered',
#  'Luxury department store announced temporary shut physical retail stores amid 19 outbreak',
#  'Coronavirus amp CBD: Navigating Shifts Consumer Behavior',
#  'day 2 Streets deserted went supermarket',
#  'line grocery store@',
#  'People grocery store dad coughing elbow',
#  'IKEA says closing U stores COVID 19 Online shopping home delivery available',
#  'brand new TRUCK talking domestic supply chain issues national emergency caused joining special guests Supply Chain',
#  'COVID19s impact retail: Store closings online sales virtual styling',
#  '29% Americans shopping online groceries 22% week according CivicScience data',
#  'need head buy groceries supermarkets remain openjust remember practice social distancing proper hygiene',
# ...
#  'lockdown helping community slashing VC prices 75% World watching',
#  'got local grocery store PLENTY Lets look folks',
#  'IGA St LeonardÂ\x92s (train station) marking vegetable prices',
#  'Community Corner Wednesday members working hard combat COVID19 provide crucial support communities Click learn PennsylvaniaÂ\x92s banks now:',
#  'Sign times Day boff joined saddos st 530 queue @ Tesco Extra',
#  'Sign times Trying @ Tesco Extra',
#  'Lets fight promoting shopping online Buy home sell home',
#  'Yo people saying price gouging/marking cost TP read: 1) surplus TP COVID19 2) TP separate commercial supplier disrupt normal consumer supply 3) cost TP factored cost deal',
#  'Aldi: 9 am7 pm Giant Eagle/Market District/GetGo: 7 am10 pm Trader JoeÂ\x92s: 9 am7 pm Walmart: 6 am11 pm Check list adjusted hours response COVID19 pandemic local grocery stores supermarkets',
#  'halt rise house prices',
#  'Â\x93ItÂ\x92s consumer response toilet paper EuropeÂ\x94 said Alexander Korbut deputy head Russian Grain Union',
#  'Drive U Commerce 2020 Change',
#  'Report businesses pricegouging Covid19 Â\x96 Consumer Goods Council',
#  'Today arrived county regular grocery store starting cleaned',
#  'advise steps place working people aged 70+ Covid19 mum works supermarket obviously canÂ\x92t work home recÂ\x92d guidance employer conscientious worker feels obliged wil',
#  'Sir Whats view consumer finance focussed NBFCs light covid19 impact',
#  'Internet analyst Aaron Kessler collaborated RJ Consumer analysts publish COVID19 Impact Consumer: RJ Consumer Survey amp Updated Sector Thoughts concerning consumer reactions plans response economic impacts deriving COVID19 effects',
#  'Stay tunedÂ higher gold prices coming soon George MillingStanley',
#  'recent pandemic facing uncharted territory Heres restaurants diversify business account unexpected change consumer behavior:',
#  'eMarketer: COVID19s business consumer impact Europe:',
#  'Christ people queuing street supermarket Madrid dont know X people allowed inside time',
#  'consumer behavior impact',
#  'Healthcare workers truck drivers food delivery peeps grocery store employees restaurant staff preparing away meals',
#  'Letter sent home today COVID19 Social Supermarket information found previous tweet',
#  'Bleakest Economic Views Come FrontRow View Fallout',
#  'looking remote video editor hit discuss prices',
#  'News COVID19 Retail Store Closures',
#  'Confirmed symptoms: advised doctor quarantine Signedup online shopping delivery slots available 7th April Customer Service number playing muzak new reality',
#  'supermarket ikea donÂ\x92t know shelves',
#  'Canadas grocers able demand amid COVID19 outbreak food producers concerned impact border restrictions agricultural food production',
#  'major supermarkets add option online grocery shopping customers donate items',
#  'husband hit 3 supermarkets amp couldnÂ\x92t find single leg chicken little 70s remember lines parents stood stick butter CeausescuÂ\x92s Romania Protip mom: Figure delivery truck arrives amp applied NJ',
#  '3 months start declining cases',
#  'heading local grocery store learn items sense stock ways prepare COVID19 Canned goods Prescription medications OTC Medications',
#  'Paul Bartholomew Sebastian Lewis discuss impact steel iron prices markets return normal:',
#  'ItÂ\x92s unprecedented times retail foodservice world writes onset COVID19 meant shops multinational brands small local independents decisions immediate future',
#  'utterly disgraceful receipt shows charged Â£999 Paracetamol pharmacies independently owned run come',
#  'Question @ Springs Theatre',
#  'Ebay urged clamp people profitting Covid19 outbreak sellers vastly inflate prices common household goods toilet paper antibacterial wipes Read here:',
#  'Investigation consumer behavior Nielsen Covid19 times',
#  'home: *DoesnÂ\x92t need cough once* grocery store:',
#  'Today saw man wearing medical mask ski goggles gardening gloves grocery store barely registers',
#  'gave lady stink eye grocery store 20+ rolls toilet paper buggy cant buy pandemic matter principle Sure hope thing clears soon thing gonna messy fast',
#  'watershed moment online grocery shopping article perspective COVID 19 shifting grocery industry',
#  'Hey work home WhatÂ\x92s plan construction workers grocery store cashiers hourly workers facing daily exposure COVID19',
#  'Scientific article ionization air viruses',
#  'Oman | outbreak looks set hit nascent nonoil sectors economy Oman working ways reduce impact plunging oil prices precarious finances Reuters',
#  'hope parents dont mental panic buying single food item possible buy want need theyll plenty',
#  'Thanet need selfisolate want near family serviced accommodation Broadstairs available Check website availability prices 0800 246 1988',
#  '1 teaches Ethics persons follow OYO offers turn Hotels Quarantine Centres amid #',
#  'Went grocery store opened people standing line staying 6 ft away',
#  'Toronto Exercises Bylaw Exemption Permit 24/7 Inventory Deliveries Response COVID19 | McCarthy TÃ©trault',
#  'Listen BBC regional radio stations morning Shoppercentrics Jamie Rayner discusses impact Covid19 retail industry',
#  'sitting home blowing money online shopping',
#  'isnt food grocery store dinner',
#  'Virus: 10 emerging PostCoronavirus World',
#  'went New York Supermarket todayCOVID19 sawhttps://tco/pmYtsFc3xy',
#  'Gas prices going COVID19',
#  'percent stores France Spain Austria closed local governments',
#  'new wave stores locking shop short term industry scrambles shut virus rocking global community',
#  'Latest Response Starting March 15 Walmart Neighborhood open 6 11 pm notice Remains Open',
#  'Temporarily Closes Stores Nationwide Response Outbreak Remain Open',
#  'Temporarily Closes Stores Business Offices Response (COVID19) Remains Open',
#  'Supermarkets working meet customersÂ\x92 needs coronavirus pandemic state shuts addressing employeesÂ\x92 concerns interactions public',
#  'Hahahahahaha grocery store slim pickinsÂ\x92',
#  'marketers changes consumer behaviour changes daily basis COVID19',
#  'spreads Europe rest world spread changes consumer behaviour mean',
#  'IKEA outlets Switzerland closed 17 March 19 April People online shopping period',
#  'Lets scammers bay work COVID19 bay Checks government',
#  'ACCC issues advice consumer rights obligations event travel cancellations COVID19 iTWire: ACCC issues advice consumer rights obligations event travel cancellations COVID19Â Â iTWire',
#  'People talk lockdown quarantine live theres ton traffic lots cars grocery store restaurant parking lots People coming going',
#  'Coronavirus reshape retail consumer landscape',
#  'Granville Island Public Market remain open asking shoppers save hour (910am) seniors Remember: dont panic buy pick essentials dont',
#  'thing meaning askdoes sell boxes milk arent normal jugs coolers theyre grocery store shelf amp long remain unopened dont need refrigeration',
#  'Oil prices 2002 20 years',
#  'school fees refunded causes closures article () updated situation develops',
#  'guess new normal hitting grocery store 0600 (TP gone 0645)',
#  'Sainsburys announces elderlyonly opening hours',
#  'supermarkets Scotland amid',
#  'went grocery store got needed look pandemic quickly started',
#  'Arabia bracing economic downturn prices plummet pandemic',
#  'start testing people grocery store',
#  'Key Consumer Thresholds Identified Outbreak Evolves',
#  'insensitive increasing prices time scourge plaguing world Shows touch Â\x93SKYÂ\x94 reality understand customer service',
#  'Whats scarier buying $link sale prices knowing',
#  'bought 4 rolls eBay $1650 Prices shooting 1 single roll $75K calling Corona Money going Corona Gold',
#  'Today year 2020 rationed bag potatoes son family gave 75 year old father pkg TP couldnÂ\x92t find grocery store',
#  'Key Thresholds Identified Outbreak Evolves Nielsen',
#  'result consumers homebound month (or more)',
#  'Raja Kali Major supply demand disruptions confounded fear wavering consumer confidence stock market free falls fiscal policy start economy Available',
#  'Agar main delhi main kisi se station main milne jau toh mujhe kaha se milega 50 ka tkt',
#  'Netherlands largest supermarket chain placed ad asking people hoard food',
#  'prices slump reaches 50 states plunges 1300 points open plans bail hardhit industries amp cut checks Americans little reassure investors',
#  'Heading New Normal | Key Consumer Behavior Thresholds Identified Evolves Nielsen',
#  'state local overheard elderly couple saying Â\x93what going came way cant items listÂ\x94 wanted weekly shop',
#  'Consumer related stocks trading coming quarantines PFGC NCMI PLNT',
#  'Financial Consumer Agency Canada (FCAC) monitoring rapid evolution COVID19 assessing impacts banks regulated entities (REs) FCAC Information:',
#  'Â\x93They donÂ\x92t need LetÂ\x92s thisÂ\x94',
#  'HEY CINCINNATI: Need shop groceries new grocery store times area COVID19 coronavirus latest:',
#  'Way Brad Kimberly',
#  'fulltime grocery store workers find unlike rest western civilization working normal hours expected work overtime face',
#  'realized majority deaths corona virus people age 65 instead calling COVID19 calling boomer consumer',
#  'Starting tomorrow 8am download book 99 cents End world prices',
#  'Canadas grocers able demand amid COVID19 outbreak food producers expressing concern impact border restrictions Canadas agricultural food production March 18 2020 01:00AM | By: Laura ClemenÂ',
#  'consumer reports Corona virus website Facts facts',
#  '{UPDATED MACH 18} Total COVID19 Confirmed Cases Outside China',
#  'think arenÂ\x92t people licking apples broccoli produce section supermarket Covid19 youÂ\x92re taking reality',
#  'Nahi amma haldi wala pani peenay se corona nai marta',
#  'able need youÂ\x92re trying grocery shopping food purchasing period consider following: 1 early wait lines',
#  '200 outdoor locations UK pledged possible open public coming weeks amp charge usual ticket prices Read more:',
#  'Today middleaged white man *stole* toilet paper aunts shopping cart outside grocery store opening car ASKED GOT SWOOOOOOP Yall',
#  '',
#  'EXACTLY said bc work grocery store im basically putting time hours time running heads chopped bc covid19',
#  'drew people',
#  'COVID19 Retail Store Closures WWD',
#  'cvnts hiking prices toilet roll paracetamolfvck',
#  'SayEntrepreneur: RT alinaka: Ministry RwandaTrade fixed food prices order prevent markets hiking outbreak',
#  'COVID19s business consumer impact Europe:',
#  'ur telling donÂ\x92t expect online shopping spending money iÂ\x92m making covid19 quarantining',
#  'Read impact COVID19 consumer behavior',
#  'DC grocery store hours coronavirus COVID19 | WUSA9',
#  'need strict national policy state city follows home minimum 2 weeks Business economy consumer quicker recovery',
#  'Grocery store reups Ground Beef',
#  'response plans include prioritizing frequent testing covid19 med staff responders grocery store workers Gas station attendants hubs dense contact',
#  'Kids Western innovated masks prices skyrocketed sanctions Kids Eastern',
#  'iTWire ACCC issues advice consumer rights obligations event travel cancellations COVID19',
#  'dont know covid19 causing exploitation consumers bought litre Dasani water 150/ nakuru KRA review',
#  'Obamacare Drives Hospital Consolidation Raising Prices Patients',
#  'lady thatÂ\x92s customer street yelled outside going came grocery store',
#  'village PerlisKuala Sanglangmy grandma opened grocery store earn living kidthat situation',
#  'work lockdown Covid19 quarantine ainÂ\x92t long supermarket stays open R P',
#  'realize consumer driven economy comes trade China donÂ\x92t anymore',
#  'happened town reminder Â\x93Wuhan VirusÂ\x94 like ItÂ\x92s COVID19/coronavirus virus excuse racial profiling excuse racial profiling',
#  'current prices add',
#  'Tie courier companies intensify online shopping online shopping',
#  'sales rise fears trigger personal safety concerns',
#  'money consumer cashier probably reason COVID19 prolific',
#  'Supermarket owners RN',
#  'reminds doesnÂ\x92t money Â\x93stock fridgeÂ\x94 w food amidst',
#  'Coronavirus: Railways increases platform ticket prices times',
#  'Thinking people gotten covid19 going overcrowded supermarket stockpile toilet paper afraid getting covid19',
#  'people taking advantage people desperate need putting prices products high demand caused hope people shops things normal place',
#  'Owner satu satunya supermarket kat tempat aku kena covid 19 Obviously staffs pun kena quarantine Means itÂ\x92ll closed',
#  '6am Asda supermarket Wembley London',
#  'hear people rushing supermarket doors ignoring elderly/special needs rule',
#  'main supermarket Lyon lockdown shoppers 1m apart calm queues plenty food different picture UK got restrictions',
#  'excessive price increases necessities report office',
#  'fellow restaurateurs find closing restaurants coming days LDN frontline food distribution desperately need excess stock gave yesterday help',
#  'Social distancing Danish Supermarket things making enh',
#  'report business inflating prices purpose outbreak Far companies putting Report',
#  'Bread gone UK grocery store Tesco Daventry',
#  'prices goods etc time',
#  'Major Grocery Store Chains Changing Hours Coronavirus Pandemic',
#  'pin pads ATM machines grocery store registers dirtiest germiest diseased thing think Fun fact: COVID19 grocery shopping dont touch k',
#  'Let bits eradicate Joseph sanitising trolleys London supermarket',
#  'wife gets grocery store',
#  'DNA privateers predators Think Cambridge Analytica intimate personal data social graph consumer data need guardrails testing website database',
#  'Illinois Retail Merchants Association Announces COVID19 Grocery Store Hours Senior Citizens',
#  'local grocery store knows',
#  'heard parts neighboring Pennsylvania shutting liquor stores supply run today oh hit grocery store',
#  'Dalby Chamber Commerce labelled stripping supermarket shelves unAustralian Report 7NEWS 6pm',
#  'FAO lost job recent weeks Covid 19 pop local store check recruiting Retail experience essential',
#  'Video Dinosaur Shopping Gorey Covid 19 Outbreak Emerges Online',
#  'Corona change Grocerry Industry Forever Reoort',
#  'neighbour come supermarket Coronavirus epidemic got',
#  'weekly supermarket sweep maybe capri suns',
#  'Supermarket job openings',
#  'New motto till coronavirus passes: Â\x92 Â\x92 Â\x93 Goodbye online shopping (for now)',
#  'traveling grocery store bike La Croix',
#  'meal centre homeless mum runs church shut indefinitely cook 200 meals lunch 2 days week Depend supermarket food donations volunteers hom',
#  'Self distancing doesnt work grocery store line ups Impossible',
#  'Spain controlling ppl enter grocery store',
#  'Cycling Kilburn high road morning 8 single supermarket passed queue outside 30/40 people',
#  'economy held consumer spending meet Covid19',
#  'expected waiting line enter grocery store',
#  'Grocery stores restocked daily basis day',
#  'shop want HUNDREDS people grocery store cant sit restaurant BS',
#  'bravo Supermarkets small country towns looking locals town Australia supermarket',
#  'know probably suffering total overload share photo took morning line waiting local grocery store Naples Florida beaches closed Feels real',
#  'UK stubborn child Europe EU include ventilator supply scheme IÂ\x92m convinced current panic buying know depend EU food Covid 19 showing need strong ties close neighbours',
#  'major supermarket chain taking steps reduce spread COVID 19 stores',
#  'COVID Defensive portfolio include $PLIN food meat stock currently oversold ChinaÂ\x92s equivalent $HRL continues rally include $WMT $CLX $CTXS $BNTX $HE',
#  'work major grocery store want self quarantine paid dip earned vacation time way paid leave diagnosed + covid19',
#  'amp cash bought chains deep combined freezer morgue/borg',
#  'local supermarket',
#  'food dog stock COVID 19 gone far',
#  '*me boys mask prices gone high',
#  'Church Jesus Christ Latterday Saints closes Distribution retail stores limits hours response COVID19 concerns',
#  ...]

# %%
# Tokenization means spliting the words
# for line in positive_tweet_list:
#     print(line)
#    for token in line.split():
#        print(token)          # we are creating a lamda function and loop is running like that

# %%
pos_tokens = [token for line in positive_tweet_list  for token in line.split()]
neg_tokens = [token for line in negative_tweet_list  for token in line.split()]
neut_tokens = [token for line in neutral_tweet_list  for token in line.split()]

# %%
pos_tokens
# Out:
# ['advice',
#  'Talk',
#  'neighbours',
#  'family',
#  'exchange',
#  'phone',
#  'numbers',
#  'create',
#  'contact',
#  'list',
#  'phone',
#  'numbers',
#  'neighbours',
#  'schools',
#  'employer',
#  'chemist',
#  'GP',
#  'set',
#  'online',
#  'shopping',
#  'accounts',
#  'poss',
#  'adequate',
#  'supplies',
#  'regular',
#  'meds',
#  'order',
#  'Coronavirus',
#  'Australia:',
#  'Woolworths',
#  'elderly',
#  'disabled',
#  'dedicated',
#  'shopping',
#  'hours',
#  'amid',
#  'COVID19',
#  'outbreak',
#  'food',
#  'stock',
#  'dont',
#  'panic',
#  'FOOD',
#  'need',
#  'Stay',
#  'calm',
#  'stay',
#  'safe',
#  'news',
#  'regionÂ\x92s',
#  'confirmed',
#  'COVID19',
#  'case',
#  'came',
#  'Sullivan',
#  'County',
#  'week',
#  'people',
#  'flocked',
#  'area',
#  'stores',
#  'purchase',
#  'cleaning',
#  'supplies',
#  'hand',
#  'sanitizer',
#  'food',
#  'toilet',
#  'paper',
#  'goods',
#  'reports',
#  'Cashier',
#  'grocery',
#  'store',
#  'sharing',
#  'insights',
#  'prove',
#  'credibility',
#  'commented',
#  'Im',
#  'Civics',
#  'class',
#  'know',
#  'Im',
#  'talking',
#  'COVID19',
#  'retail',
#  'store',
#  'classroom',
#  'Atlanta',
#  'open',
#  'walkin',
#  'business',
#  'classes',
#  'weeks',
#  'beginning',
#  'Monday',
#  'March',
#  '16',
#  'continue',
#  'process',
#  'online',
#  'phone',
#  'orders',
#  'normal',
#  'Thank',
#  'understanding',
#  'Me:',
#  'dont',
#  'need',
#  'stock',
#  'food',
#  'Ill',
#  'Amazon',
#  'deliver',
#  'need',
#  'Amazon:',
#  'ADARA',
#  'Releases',
#  'COVID19',
#  'Resource',
#  'Center',
#  'Travel',
#  'Brands:',
#  'Insights',
#  'Help',
#  'Travel',
#  'Brands',
#  'Stay',
#  'UpToDate',
#  'Consumer',
#  'Travel',
#  'Behavior',
#  'Trends',
#  'Lines',
#  'grocery',
#  'store',
#  'unpredictable',
#  'eating',
#  'safe',
#  'alternative',
#  'Find',
#  'avoiding',
#  'restaurants',
#  'right',
#  'now:',
#  'arent',
#  'struggling',
#  'consider',
#  'donating',
#  'food',
#  'bank',
#  'nonprofit',
#  'demand',
#  'services',
#  'increase',
#  'COVID19',
#  'impacts',
#  'jobs',
#  'peoples',
#  'way',
#  'life',
#  'Yes',
#  'buy',
#  'need',
#  'whats',
#  'point',
#  'posting',
#  'photos',
#  'people',
#  'supermarket',
#  'load',
#  'stuff',
#  'buying',
#  'elderly',
#  'parents',
#  'kids',
#  'siblings',
#  'etc',
#  'cant',
#  'buy',
#  'needs',
#  'viral',
#  'Covid19',
#  'alr',
#  'Worried',
#  'impact',
#  'current',
#  'COVID19',
#  'pandemic',
#  'finances',
#  'WeÂ\x92ve',
#  'published',
#  'tips',
#  'help',
#  'manage',
#  'money',
#  'challenging',
#  'times',
#  'supermarket',
#  'like',
#  'judged',
#  'Curious',
#  'think',
#  'retail',
#  'shoppers',
#  'lot',
#  'online',
#  'shopping',
#  'bc',
#  'theyre',
#  'home',
#  'unable',
#  'think',
#  'spooked',
#  'extra',
#  'pair',
#  'shoes',
#  'People',
#  'posting',
#  'sharing',
#  'photos',
#  'half',
#  'completely',
#  'shelves',
#  'calling',
#  'people',
#  'dumb',
#  'idiots',
#  'shopping',
#  'grocery',
#  'store',
#  'lol',
#  'Dear',
#  'Coronavirus',
#  'Ive',
#  'following',
#  'social',
#  'distancing',
#  'rules',
#  'staying',
#  'home',
#  'prevent',
#  'spread',
#  'Ive',
#  'spent',
#  'alarming',
#  'money',
#  'shopping',
#  'online',
#  'submit',
#  'expenses',
#  'reimbursement',
#  'Let',
#  'know',
#  'THANK',
#  'GROCERY',
#  'CLERK',
#  'Went',
#  'grocery',
#  'store',
#  'today',
#  'looked',
#  'weary',
#  'eyes',
#  'clerk',
#  'thanked',
#  'realized',
#  'thrust',
#  'line',
#  'panick',
#  'new',
#  'breed',
#  'responders',
#  'working',
#  'hard',
#  'serve',
#  'communities',
#  'work',
#  'capitalizing',
#  'demand',
#  'packaged',
#  'food',
#  'making',
#  'stay',
#  'open',
#  'opposed',
#  'closing',
#  'health',
#  'safety',
#  'Yeah',
#  'parents',
#  'risky',
#  'people',
#  'covid',
#  '19',
#  'thatÂ\x92s',
#  'stay',
#  'home',
#  'supermarket',
#  'necessary',
#  'stay',
#  'safe',
#  'CN',
#  'group',
#  '(and',
#  'Mum',
#  'live',
#  'with)',
#  'group',
#  'needs',
#  'shielded',
#  '12',
#  'weeks',
#  '(3',
#  'months)',
#  'mean',
#  'staying',
#  'hope',
#  'online',
#  'shopping',
#  'need',
#  'Hi',
#  'COVID19',
#  'Thanks',
#  'making',
#  'online',
#  'shopping',
#  'consumer',
#  'tech',
#  '(some',
#  'Chinese',
#  'group',
#  'demostrated',
#  'ELISA',
#  'test',
#  'strips',
#  'COVID19',
#  'details',
#  'lacking)',
#  'consumer',
#  'deem',
#  'waived',
#  'test',
#  'doesnÂ\x92t',
#  'come',
#  'easily',
#  'retailers',
#  'close',
#  'physical',
#  'stores',
#  'curtail',
#  'hours',
#  'result',
#  'Covid19',
#  'agoing',
#  'additional',
#  'pressure',
#  'omnichannel',
#  'alternatives',
#  'like',
#  'grocery',
#  'delivery',
#  'curbside',
#  'pick',
#  'Check',
#  'folks',
#  'Cal',
#  'like',
#  'idea',
#  'La',
#  'Habra',
#  'supermarket',
#  'offers',
#  'special',
#  'hours',
#  'seniors',
#  'amid',
#  'COVID19',
#  'crisis',
#  'Love',
#  'hate',
#  'head',
#  'advice',
#  'amp',
#  'Blip',
#  'lives',
#  'itÂ\x92s',
#  'happening',
#  'DonÂ\x92t',
#  'whinge',
#  'canÂ\x92t',
#  'Dont',
#  'panic',
#  'buy',
#  'food',
#  'wont',
#  'run',
#  'spend',
#  'time',
#  'family',
#  'use',
#  'common',
#  'sense',
#  'work',
#  'retail',
#  'stock',
#  'older',
#  'customers',
#  'frank',
#  'comes',
#  'store',
#  'bread',
#  'sees',
#  'shelve',
#  'donÂ\x92t',
#  'worry',
#  'pal',
#  'IÂ\x92ve',
#  'saved',
#  '1',
#  'pat',
#  'n',
#  'beans',
#  'disciplined',
#  'Yes',
#  'care',
#  'IÂ\x92ve',
#  'got',
#  'Supermarket',
#  'workers',
#  'frontline',
#  'COVID19',
#  'extraordinary',
#  'times',
#  'retail',
#  'extreme',
#  'pressure',
#  'shopping',
#  'remain',
#  'calm',
#  'thank',
#  'workers',
#  'shelves',
#  'stocked',
#  'checkouts',
#  'moving',
#  'biggest',
#  'supermarket',
#  'chain',
#  'United',
#  'States',
#  '453000',
#  'employees',
#  'receive',
#  'sick',
#  'leave',
#  '2',
#  'employees',
#  'tested',
#  'positive',
#  'COVID19',
#  'wont',
#  'provide',
#  'paid',
#  'sick',
#  'leave',
#  'Instead',
#  'paid',
#  'sick',
#  'leave',
#  'providing',
#  '2',
#  'weeks',
#  'paid',
#  'leave',
#  'people',
#  'test',
#  'positive',
#  'COVID19',
#  'placed',
#  'mandatory',
#  'quarantine',
#  'insufficient',
#  'protect',
#  'staff',
#  'public',
#  'especially',
#  'little',
#  'testing',
#  'av',
#  'followed',
#  'went',
#  'shopping',
#  'days',
#  'ago',
#  'pain',
#  'necessary',
#  'Protect',
#  'Grocery',
#  'Shopping',
#  'Consumer',
#  'Reports',
#  'needs',
#  'said:',
#  'going',
#  'grocery',
#  'store',
#  'completely',
#  'safely',
#  'Meaning',
#  'risk',
#  'getting',
#  'spreading',
#  'reduce',
#  'risk',
#  'staying',
#  '6',
#  'ft',
#  'people',
#  'amp',
#  'washing',
#  'hands',
#  'cant',
#  'eliminate',
#  '1/3',
#  'getting',
#  'real',
#  'world',
#  'know',
#  'itÂ\x92s',
#  'real',
#  'worlds',
#  'sign',
#  'petition',
#  'food',
#  'bev',
#  'people',
#  'Colorado',
#  'UPDATE:',
#  'sure',
#  'check',
#  'local',
#  'listings',
#  'open/closed',
#  'times',
#  'ChickfilA',
#  '(Drive',
#  'only)',
#  'Starbucks',
#  '(Using',
#  'togo',
#  'model)',
#  'Early',
#  'closing',
#  'include',
#  'King',
#  'Soopers',
#  'Sams',
#  'Club',
#  'etc',
#  'supermarket',
#  'La',
#  'Habra',
#  'trying',
#  'help',
#  'local',
#  'seniors',
#  'COVID19',
#  'pandemic',
#  'opening',
#  'doors',
#  'halfhour',
#  'early',
#  'day',
#  'exclusively',
#  'shoppers',
#  '65',
#  'older',
#  'supermarket',
#  'La',
#  'Habra',
#  'trying',
#  'help',
#  'local',
#  'seniors',
#  'COVID19',
#  'pandemic',
#  'opening',
#  'doors',
#  'halfhour',
#  'early',
#  'day',
#  'exclusively',
#  'shoppers',
#  '65',
#  'older',
#  'Kids',
#  'Mild',
#  'COVID19',
#  'Symptoms',
#  'Chance',
#  'Transmission',
#  'High:',
#  'Study',
#  'confirm',
#  'store',
#  'signage',
#  'says',
#  'youre',
#  'taking',
#  'extra',
#  'precautions',
#  'light',
#  'COVID19',
#  'staff',
#  'stating',
#  'changing',
#  'efforts',
#  'management',
#  'protect',
#  'retail',
#  'workers',
#  'Speed',
#  'crucial',
#  'fringing',
#  'idiots',
#  'like',
#  'caused',
#  'prices',
#  'rise',
#  'amp',
#  'create',
#  'shortages',
#  'Hes',
#  'probably',
#  'wasted',
#  'lot',
#  'money',
#  'expiry',
#  'dates',
#  'Shopkeepers',
#  'use',
#  'rationing',
#  'fair',
#  'customers',
#  'Consumer',
#  'Financial',
#  'Protection',
#  'Bureau',
#  'reported',
#  'employee',
#  'tested',
#  'positive',
#  'COVID19',
#  'Federal',
#  'financial',
#  'regulators',
#  'mandating',
#  'employees',
#  'work',
#  'home',
#  'daughter',
#  '16',
#  'stories',
#  'like',
#  'friends',
#  'supermarket',
#  'jobs',
#  'said',
#  'adults',
#  'act',
#  'like',
#  'COVID19',
#  'fault',
#  'stand',
#  'middleaged',
#  'woman',
#  'refused',
#  '5',
#  'boxes',
#  'need',
#  'help',
#  'seniors',
#  'Stores',
#  'Charlotte',
#  'continue',
#  'voluntarily',
#  'shut',
#  'doors',
#  'concerns',
#  'tough',
#  'decision',
#  'stores',
#  'deem',
#  'necessary',
#  'Remember',
#  'possible',
#  'online',
#  'shopping',
#  'option',
#  'want',
#  'support',
#  'businesses',
#  'like',
#  'shopping',
#  'HEB',
#  'fan',
#  'Appreciate',
#  'efforts',
#  'limit',
#  'food',
#  'shortage',
#  'amp',
#  'COVID19',
#  'spreading',
#  'tho',
#  'concern',
#  'lack',
#  'push',
#  'curbside',
#  'pickups',
#  'amp',
#  'delivery',
#  '3%',
#  'additional',
#  'charge',
#  'item',
#  'cart',
#  'Good',
#  'tackling',
#  'Covid19',
#  'spreading',
#  'implement',
#  'new',
#  'policy',
#  'restrict',
#  'consumers',
#  'hoarding',
#  'goods',
#  'supermarket/grocery',
#  'stores',
#  'point',
#  'creating',
#  'safety',
#  'measurements',
#  'people',
#  'canÂ\x92t',
#  'changed',
#  'selfish',
#  'Ive',
#  'able',
#  'Doggos',
#  'food',
#  'panic',
#  'buying',
#  'european',
#  'supply',
#  'issues',
#  'caused',
#  'Covid19',
#  'ordered',
#  'Amazon',
#  'paid',
#  'Â£20',
#  'wonder',
#  'Ill',
#  'Doggo',
#  'rations',
#  'government',
#  'says',
#  'start',
#  'social',
#  'distancing',
#  'work',
#  'retail',
#  'cant',
#  'talk',
#  'customers',
#  'store',
#  'lol',
#  'fml',
#  'Im',
#  '100%',
#  'going',
#  'catch',
#  'covid19',
#  'DEAR',
#  'HOARDER',
#  ':',
#  'Mum',
#  'actually',
#  'mounted',
#  'dispenser',
#  'soap',
#  'wash',
#  'hand',
#  'enter',
#  'supermarket',
#  'chance',
#  'Covid19',
#  'list',
#  'plethora',
#  'Â\x91To',
#  'DoÂ\x92sÂ\x92',
#  'unfortunately',
#  'day',
#  'jobs',
#  'health',
#  'care',
#  'supermarket',
#  'retail',
#  'bucking',
#  'IÂ\x92ll',
#  'taking',
#  'care',
#  'sick',
#  'feeding',
#  'hungry',
#  'read',
#  'LAVA',
#  'Covid19',
#  'Statement',
#  'amp',
#  'Announcement',
#  'Online',
#  'Store',
#  'Consumer',
#  'Electronics',
#  'Computing',
#  'Interfaces',
#  'here:',
#  'increase',
#  'workers',
#  'online',
#  'shopping',
#  'add',
#  'time',
#  'slots',
#  'pick',
#  'delivery',
#  'hire',
#  'workers',
#  'short',
#  'time',
#  'business',
#  'shut',
#  'people',
#  'stocking',
#  'soap',
#  'hand',
#  'sanitiser',
#  'toilet',
#  'roll',
#  'leaving',
#  'shelves',
#  'rest',
#  'realise',
#  'stop',
#  'spread',
#  'people',
#  'need',
#  'able',
#  'wash',
#  'hands',
#  'opportunities',
#  'amp',
#  'challenges',
#  'caused',
#  'apparent',
#  'current',
#  'pandemic',
#  'stores',
#  'closed',
#  'physical',
#  'locations',
#  'consumers',
#  'turning',
#  'online',
#  'shopping',
#  'Actual',
#  'footage',
#  'trying',
#  'grocery',
#  'store',
#  'weekend',
#  'IÂ\x92m',
#  'sure',
#  'yÂ\x92all',
#  'toilet',
#  'paper',
#  'remember',
#  'weÂ\x92re',
#  'FYI:',
#  'checked',
#  'freeze',
#  'dried',
#  'food',
#  'companies',
#  'sold',
#  'stock',
#  'backlogged',
#  'weeks',
#  'Went',
#  'store',
#  'today',
#  'canned',
#  'food',
#  'gone',
#  'needed',
#  'toilet',
#  'paper',
#  'actually',
#  'got',
#  'pack',
#  '12',
#  'rolls',
#  'got',
#  'milk',
#  'cat',
#  'treats',
#  'Thank',
#  'god',
#  'Save',
#  'Foods',
#  'stuff',
#  '100',
#  'cases',
#  'Covid19',
#  'province',
#  'panic',
#  'buying',
#  'common',
#  'safe',
#  'work',
#  'amid',
#  'coronavirus',
#  'colleague',
#  'texts',
#  '8pm',
#  'ask',
#  'need',
#  'supermarket',
#  'Me:',
#  'buy',
#  '2',
#  'cartons',
#  'unsweetened',
#  'almond',
#  'milk',
#  'try',
#  'convince',
#  'Im',
#  'millennial',
#  'material',
#  'sh*t',
#  'like',
#  'Given',
#  'restrictions',
#  'COVID',
#  '19',
#  'FIC',
#  'postponed',
#  'til',
#  '17',
#  '18',
#  'Nov',
#  'Interest',
#  'food',
#  'security',
#  'increasing',
#  'amp',
#  'meeting',
#  'demand',
#  'thought',
#  'provoking',
#  'discussions',
#  'examining',
#  'food',
#  'issues',
#  'experienced',
#  'epidemic',
#  'amp',
#  'likely',
#  'experience',
#  'going',
#  'forward',
#  'people',
#  'taking',
#  'COVID19',
#  'stuck',
#  'indoors',
#  'food',
#  'decided',
#  'wasnÂ\x92t',
#  'necessary',
#  'stock',
#  'gtgtgtgt',
#  'retail',
#  'store',
#  ...]

# %%
# Get Most Commonest Keywords
from collections import Counter

# %%
#creating function for getting most common words up to 40
def get_tokens(docx,num=40):
    word_tokens = Counter(docx)
    most_common = word_tokens.most_common(num)
    result = dict(most_common)
    return result

# %%
#creating function for getting most common top 20
def get_top_tokens(docx,num=20):
    word_tokens = Counter(docx)
    most_common = word_tokens.most_common(num)
    result = dict(most_common)
    return result

# %%
get_tokens(pos_tokens)
# Out:
# {'store': 1887,
#  'prices': 1842,
#  'grocery': 1605,
#  'supermarket': 1580,
#  'food': 1478,
#  'COVID19': 1448,
#  'amp': 1418,
#  'people': 1269,
#  '19': 1018,
#  'shopping': 941,
#  'online': 907,
#  'consumer': 864,
#  'like': 861,
#  'need': 736,
#  'workers': 727,
#  'pandemic': 696,
#  'hand': 666,
#  'help': 656,
#  'sanitizer': 630,
#  'demand': 614,
#  'time': 587,
#  'home': 569,
#  'stock': 533,
#  'COVID': 494,
#  'going': 469,
#  'work': 424,
#  'local': 400,
#  'Covid19': 392,
#  'stores': 371,
#  'paper': 362,
#  'Consumer': 362,
#  'delivery': 356,
#  'know': 350,
#  'toilet': 348,
#  'buy': 341,
#  'shelves': 339,
#  'new': 337,
#  'staff': 335,
#  '2': 318,
#  'day': 302}

# %%
get_top_tokens(pos_tokens)
# Out:
# {'store': 1887,
#  'prices': 1842,
#  'grocery': 1605,
#  'supermarket': 1580,
#  'food': 1478,
#  'COVID19': 1448,
#  'amp': 1418,
#  'people': 1269,
#  '19': 1018,
#  'shopping': 941,
#  'online': 907,
#  'consumer': 864,
#  'like': 861,
#  'need': 736,
#  'workers': 727,
#  'pandemic': 696,
#  'hand': 666,
#  'help': 656,
#  'sanitizer': 630,
#  'demand': 614}

# %%
most_common_pos_words = get_tokens(pos_tokens)
most_common_neg_words = get_tokens(neg_tokens)
most_common_neut_words = get_tokens(neut_tokens)

# %%
# Plot with seaborn
neg_df = pd.DataFrame(most_common_neg_words.items(),columns=['words','scores'])

# %%
neg_df
# Out:
#          words  scores
# 0       prices    2148
# 1         food    1653
# 2        store    1438
# 3  supermarket    1426
# 4      grocery    1225
# 5       people    1213
# 6      COVID19    1212
# 7          amp    1077
# 8           19     912
# 9       demand     791

# %% [markdown]
# # MOST REPEATED NEGATIVE WORDS

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=neg_df)

# %% [markdown]
# # MOST REPEATED POSITIVE WORDS

# %%
pos_df = pd.DataFrame(most_common_pos_words.items(),columns=['words','scores'])
plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=pos_df)

# %% [markdown]
# # MOST REPEATED POSITIVE WORDS

# %%
neut_df = pd.DataFrame(most_common_neut_words.items(),columns=['words','scores'])
plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=neut_df)

# %% [markdown]
# TRYING ON ANOTHER WAY BY USING WORD CLOUD

# %%
### Word Cloud
from wordcloud import WordCloud

# %%
# CREATING A FUNCTION FOR DATA VIGULATION
def plot_wordcloud(docx):
    plt.figure(figsize=(20,10))
    mywordcloud = WordCloud().generate(docx)
    plt.imshow(mywordcloud,interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
pos_docx = ' '.join(pos_tokens)
neg_docx = ' '.join(neg_tokens)
neu_docx = ' '.join(neut_tokens)

# %%
plot_wordcloud(pos_docx)

# %%
plot_wordcloud(neg_docx)

# %%
plot_wordcloud(neu_docx)

# %% [markdown]
# ## MODEL TRAINING

# %%
clean_tweet = df['clean_tweet']

# %%
#one hot encoding
sentiment_map = {"Extremely Negative":-1, "Negative":-1,"Neutral":0, "Positive":1,"Extremely Positive":1}
df['Sentiment'] = df['Sentiment'].map(sentiment_map)

# %%
sns.countplot(x='Sentiment', data=df)

# %% [markdown]
# # DIVIDING OUR DATASET INTO TRAINING AND TESTING

# %%
from sklearn.model_selection import train_test_split

train,test = train_test_split(df,test_size = 0.2,random_state=24,stratify = df.Sentiment.values) 
print("train shape : ", train.shape)
print("test shape : ", test.shape)
# Out:
# train shape :  (32925, 8)
# test shape :  (8232, 8)
